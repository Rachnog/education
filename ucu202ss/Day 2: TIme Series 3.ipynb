# %%
from pandas_datareader import data as datareader
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import timedelta
from datetime import datetime
# Out:
# /anaconda2/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data reading

# %%
data = pd.read_csv('aapl_dataset.csv', index_col = 'Date')

# %%
data = data.dropna()

# %%
data.tail()
# Out:
#                   high         low        open       close      volume  \
# Date
# 2019-12-24  284.890015  282.920013  284.690002  284.269989  12119700.0
# 2019-12-26  289.980011  284.700012  284.820007  289.910004  23280300.0
# 2019-12-27  293.970001  288.119995  291.119995  289.799988  36566500.0
# 2019-12-30  292.690002  285.220001  289.459991  291.519989  36028600.0
# 2019-12-31  293.679993  289.519989  289.929993  293.649994  25201400.0
#
#              adj close  feat_RSI_close  feat_OBV_volume  feat_ATR_close  \
# Date
# 2019-12-24  283.596924       74.436585     2.224292e+10        3.913542
# 2019-12-26  289.223602       78.678994     2.226620e+10        4.041862
# 2019-12-27  289.113831       78.405656     2.222964e+10        4.171015
# 2019-12-30  290.829773       79.598963     2.226566e+10        4.406657
# 2019-12-31  292.954712       80.999258     2.229087e+10        4.389039
#
#             feat_HT_DCPERIOD_close  feat_HT_DCPHASE_close  \
# Date
# 2019-12-24               28.454955             150.076370
# 2019-12-26               28.079039             153.345130
# 2019-12-27               27.740405             156.893808
# 2019-12-30               27.553361             160.727817
# 2019-12-31               27.941882             164.208211
#
#             feat_FUNDAMENTAL1_CHG  feat_FUNDAMENTAL2_CHG  feat_K10_FILING  \
# Date
# 2019-12-24              -0.337975               0.541358                3
# 2019-12-26              -0.408145               0.929980                0
# 2019-12-27               0.162783               0.732749                3
# 2019-12-30              -0.933116               0.980977                0
# 2019-12-31               0.383039               0.336035                1
#
#             feat_SENTIMENT_UP  feat_DIVIDEND
# Date
# 2019-12-24                  0      -0.982111
# 2019-12-26                  1      -2.587859
# 2019-12-27                  1       0.814541
# 2019-12-30                  0      -1.696447
# 2019-12-31                  0       0.176790

# %%
t = '2015-01-01'
data_train = data[:t]
data_test = data[t:]

# %%
for column in data.columns:  
    plt.figure()
    plt.title(column)
    plt.plot(range(0, len(data_train)), data_train[column])
    plt.plot(range(len(data_train), len(data_train) + len(data_test)), data_test[column])
    plt.show()

# %% [markdown]
# # Data Preparation

# %%
from sklearn.preprocessing import StandardScaler

# %%
columns_to_stationarize = ['open', 'high', 'low', 'close', 'volume', 'adj close', 'feat_OBV_volume', 'feat_ATR_close']

# %%
# scaler_y = StandardScaler()
# outputs_train = scaler_y.fit_transform(data_train.close.values.reshape(-1, 1))
# outputs_test = scaler_y.transform(data_test.close.values.reshape(-1, 1))
outputs_train = data_train.close.copy()
outputs_test = data_test.close.copy()

# scaler_x = StandardScaler()
# inputs_train = scaler_x.fit_transform(data_train)
# inputs_test = scaler_x.transform(data_test)

data_train[columns_to_stationarize] = data_train[columns_to_stationarize].pct_change()
data_test[columns_to_stationarize] = data_test[columns_to_stationarize].pct_change()

inputs_train = data_train.replace(np.inf, np.nan).fillna(0.0)
inputs_test = data_test.replace(np.inf, np.nan).fillna(0.0)

# %%
for column in inputs_train.columns:  
    plt.figure()
    plt.title(column)
    plt.plot(range(0, len(data_train)), data_train[column])
    plt.plot(range(len(data_train), len(data_train) + len(data_test)), data_test[column])
    plt.show()

# %%
WINDOW = 14
HORIZON = 1

# %%
def createXY(inputs, outputs):   
    X, Y, P = [], [], []
    for i in range(WINDOW, len(inputs)-1, 1):

        window = inputs[i-WINDOW:i].values
        future = (outputs[i+HORIZON] - outputs[i]) / outputs[i]

        X.append(window)
        Y.append(future)
        P.append(outputs[i])

    X, Y, P = np.array(X), np.array(Y), np.array(P)
    return X, Y, P

# %%
X_train, Y_train, P_train = createXY(inputs_train, outputs_train)
X_test, Y_test, P_test = createXY(inputs_test, outputs_test)

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((3695, 14, 16), (3695,), (1243, 14, 16), (1243,))

# %%
plt.figure()
plt.plot(range(0, len(Y_train)), Y_train)
plt.plot(range(len(Y_train), len(Y_train) + len(Y_test)), Y_test)
plt.show()

# %% [markdown]
# # Modeling

# %%
from keras.models import Model
from keras.layers import Dense, Dropout, GaussianNoise
from keras.layers import Input, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.regularizers import l1, l2 , l1_l2

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.metrics import r2_score, matthews_corrcoef, f1_score, mean_absolute_error
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
def nn(shape):
    main_input = Input(shape=shape, name='main_input')
    x = Flatten()(main_input)
    x = Dense(50, activation='relu')(x)
    x = Dropout(0.25)(x)
    output = Dense(1, activation = "linear")(x)
    
    final_model = Model(inputs=[main_input], outputs=[output])
    return final_model

# %%
model = nn((WINDOW, X_train.shape[2], ))
model.summary()

model.compile(optimizer='adam', loss=['mse'])

checkpointer = ModelCheckpoint(filepath="test.hdf5", verbose=0, save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(X_train, Y_train, 
              validation_data = (X_test, Y_test),
              epochs = 100, 
              batch_size = 16, 
              verbose=True, 
              callbacks=[checkpointer, es],
              shuffle=True
                )

model.load_weights("test.hdf5")
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 14, 16)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 224)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                11250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 11,301
# Trainable params: 11,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3695 samples, validate on 1243 samples
# Epoch 1/100
# 3695/3695 [==============================] - 2s 471us/step - loss: 290.1507 - val_loss: 11.8515
# Epoch 2/100
# 3695/3695 [==============================] - 2s 545us/step - loss: 23.6147 - val_loss: 3.9508
# Epoch 3/100
# 3695/3695 [==============================] - 3s 707us/step - loss: 9.4888 - val_loss: 2.1973
# Epoch 4/100
# 3695/3695 [==============================] - 2s 670us/step - loss: 4.3069 - val_loss: 1.1515
# Epoch 5/100
# 3695/3695 [==============================] - 1s 393us/step - loss: 2.4525 - val_loss: 0.7951
# Epoch 6/100
# 3695/3695 [==============================] - 1s 380us/step - loss: 1.6665 - val_loss: 0.5315
# Epoch 7/100
# 3695/3695 [==============================] - 1s 363us/step - loss: 1.0550 - val_loss: 0.3541
# Epoch 8/100
# 3695/3695 [==============================] - 1s 298us/step - loss: 0.7170 - val_loss: 0.2826
# Epoch 9/100
# 3695/3695 [==============================] - 2s 465us/step - loss: 0.5483 - val_loss: 0.1987
# Epoch 10/100
# 3695/3695 [==============================] - 1s 375us/step - loss: 0.3225 - val_loss: 0.1690
# Epoch 11/100
# 3695/3695 [==============================] - 1s 344us/step - loss: 0.3059 - val_loss: 0.1345
# Epoch 12/100
# 3695/3695 [==============================] - 1s 316us/step - loss: 0.2148 - val_loss: 0.1106
# Epoch 13/100
# 3695/3695 [==============================] - ETA: 0s - loss: 0.194 - 1s 301us/step - loss: 0.1894 - val_loss: 0.0842
# Epoch 14/100
# 3695/3695 [==============================] - 1s 320us/step - loss: 0.1602 - val_loss: 0.0638
# Epoch 15/100
# 3695/3695 [==============================] - 2s 550us/step - loss: 0.1526 - val_loss: 0.0357
# Epoch 16/100
# 3695/3695 [==============================] - ETA: 0s - loss: 0.085 - 1s 329us/step - loss: 0.0873 - val_loss: 0.0307
# Epoch 17/100
# 3695/3695 [==============================] - 1s 317us/step - loss: 0.0879 - val_loss: 0.0314
# Epoch 18/100
# 3695/3695 [==============================] - 1s 298us/step - loss: 0.0588 - val_loss: 0.0293
# Epoch 19/100
# 3695/3695 [==============================] - 2s 572us/step - loss: 0.0383 - val_loss: 0.0268
# Epoch 20/100
# 3695/3695 [==============================] - 2s 611us/step - loss: 0.0634 - val_loss: 0.0313
# Epoch 21/100
# 3695/3695 [==============================] - 1s 294us/step - loss: 0.0296 - val_loss: 0.0259
# Epoch 22/100
# 3695/3695 [==============================] - 1s 352us/step - loss: 0.0302 - val_loss: 0.0190
# Epoch 23/100
# 3695/3695 [==============================] - 1s 283us/step - loss: 0.0265 - val_loss: 0.0210
# Epoch 24/100
# 3695/3695 [==============================] - 1s 295us/step - loss: 0.0254 - val_loss: 0.0197
# Epoch 25/100
# 3695/3695 [==============================] - 1s 359us/step - loss: 0.0290 - val_loss: 0.0126
# Epoch 26/100
# 3695/3695 [==============================] - 1s 310us/step - loss: 0.0088 - val_loss: 0.0130
# Epoch 27/100
# 3695/3695 [==============================] - 1s 355us/step - loss: 0.0060 - val_loss: 0.0116
# Epoch 28/100
# 3695/3695 [==============================] - 1s 350us/step - loss: 0.0150 - val_loss: 0.0161 ETA: 0s
# Epoch 29/100
# 3695/3695 [==============================] - 1s 297us/step - loss: 0.0143 - val_loss: 0.0083
# Epoch 30/100
# 3695/3695 [==============================] - 1s 303us/step - loss: 0.0113 - val_loss: 0.0052
# Epoch 31/100
# 3695/3695 [==============================] - 1s 271us/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 32/100
# 3695/3695 [==============================] - 2s 419us/step - loss: 0.0039 - val_loss: 0.0052
# Epoch 33/100
# 3695/3695 [==============================] - 2s 466us/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 34/100
# 3695/3695 [==============================] - 1s 351us/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 35/100
# 3695/3695 [==============================] - 1s 299us/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 36/100
# 3695/3695 [==============================] - 1s 344us/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 37/100
# 3695/3695 [==============================] - 2s 418us/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 38/100
# 3695/3695 [==============================] - 1s 300us/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 39/100
# 3695/3695 [==============================] - 1s 327us/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 40/100
# 3695/3695 [==============================] - 1s 369us/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 41/100
# 3695/3695 [==============================] - 1s 350us/step - loss: 9.3997e-04 - val_loss: 0.0019
# Epoch 42/100
# 3695/3695 [==============================] - 1s 338us/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 43/100
# 3695/3695 [==============================] - 1s 309us/step - loss: 7.7687e-04 - val_loss: 0.0018
# Epoch 44/100
# 3695/3695 [==============================] - 1s 309us/step - loss: 8.2765e-04 - val_loss: 0.0018
# Epoch 45/100
# 3695/3695 [==============================] - 1s 299us/step - loss: 7.7467e-04 - val_loss: 0.0018
# Epoch 46/100
# 3695/3695 [==============================] - 1s 315us/step - loss: 7.8014e-04 - val_loss: 0.0018
# Epoch 47/100
# 3695/3695 [==============================] - 2s 455us/step - loss: 7.7114e-04 - val_loss: 0.0018
# Epoch 48/100
# 3695/3695 [==============================] - 2s 439us/step - loss: 7.6211e-04 - val_loss: 0.0018
# Epoch 49/100
# 3695/3695 [==============================] - 1s 333us/step - loss: 7.8877e-04 - val_loss: 0.0018
# Epoch 50/100
# 3695/3695 [==============================] - 2s 510us/step - loss: 7.7070e-04 - val_loss: 0.0018
# Epoch 51/100
# 3695/3695 [==============================] - 2s 591us/step - loss: 7.7193e-04 - val_loss: 0.0018
# Epoch 52/100
# 3695/3695 [==============================] - 2s 409us/step - loss: 7.8549e-04 - val_loss: 0.0018
# Epoch 53/100
# 3695/3695 [==============================] - 2s 442us/step - loss: 7.7359e-04 - val_loss: 0.0018
# Epoch 54/100
# 3695/3695 [==============================] - 1s 375us/step - loss: 7.8639e-04 - val_loss: 0.0018
# Epoch 55/100
# 3695/3695 [==============================] - 1s 318us/step - loss: 7.8529e-04 - val_loss: 0.0018
# Epoch 56/100
# 3695/3695 [==============================] - 1s 327us/step - loss: 7.8166e-04 - val_loss: 0.0018
# Epoch 57/100
# 3695/3695 [==============================] - 1s 342us/step - loss: 7.9257e-04 - val_loss: 0.0018
# Epoch 58/100
# 3695/3695 [==============================] - 2s 493us/step - loss: 7.8357e-04 - val_loss: 0.0018
# Epoch 59/100
# 3695/3695 [==============================] - 2s 512us/step - loss: 7.6437e-04 - val_loss: 0.0018

# %% [markdown]
# # Evaluation

# %%
pred_test = model.predict(X_test)

# %%
print(mean_absolute_error(Y_test, pred_test), r2_score(Y_test, pred_test))
# Out:
# 0.012887590755638835 -6.260932172813067

# %%
plt.figure(figsize = (15, 5))
plt.plot(Y_test)
plt.plot(pred_test, ls = '--')
plt.show()

# %%
signal = np.sign(pred_test)

# %%
backtest_df = pd.DataFrame(
    {
        'real_change': Y_test.flatten(),
        'signal': signal.flatten()
    }
)

# %%
backtest_df.head(10)
# Out:
#    real_change  signal
# 0     0.001062    -1.0
# 1    -0.035013    -1.0
# 2     0.056533     1.0
# 3     0.031134     1.0
# 4    -0.014634     1.0
# 5     0.012547    -1.0
# 6     0.000169    -1.0
# 7     0.007670     1.0
# 8     0.003178     1.0
# 9    -0.008421     1.0

# %%
portfolio = backtest_df['real_change'] * backtest_df['signal']

# %%
plt.figure(figsize = (15, 5))
plt.plot(portfolio.cumsum().values, label = 'NN strategy')
plt.plot(pd.Series(Y_test.flatten()).cumsum(), label = 'AAPL HODL')
plt.legend()
plt.show()
