# %%
from pandas_datareader import data as datareader
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import timedelta
from datetime import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data reading

# %%
data = pd.read_csv('aapl_dataset.csv', index_col = 'Date')

# %%
data = data.dropna()

# %%
data.tail()
# Out:
#                   high         low        open       close      volume  \
# Date
# 2019-12-24  284.890015  282.920013  284.690002  284.269989  12119700.0
# 2019-12-26  289.980011  284.700012  284.820007  289.910004  23280300.0
# 2019-12-27  293.970001  288.119995  291.119995  289.799988  36566500.0
# 2019-12-30  292.690002  285.220001  289.459991  291.519989  36028600.0
# 2019-12-31  293.679993  289.519989  289.929993  293.649994  25201400.0
#
#              adj close  feat_RSI_close  feat_OBV_volume  feat_ATR_close  \
# Date
# 2019-12-24  283.596924       74.436585     2.224292e+10        3.913542
# 2019-12-26  289.223602       78.678994     2.226620e+10        4.041862
# 2019-12-27  289.113831       78.405656     2.222964e+10        4.171015
# 2019-12-30  290.829773       79.598963     2.226566e+10        4.406657
# 2019-12-31  292.954712       80.999258     2.229087e+10        4.389039
#
#             feat_HT_DCPERIOD_close  feat_HT_DCPHASE_close  \
# Date
# 2019-12-24               28.454955             150.076370
# 2019-12-26               28.079039             153.345130
# 2019-12-27               27.740405             156.893808
# 2019-12-30               27.553361             160.727817
# 2019-12-31               27.941882             164.208211
#
#             feat_FUNDAMENTAL1_CHG  feat_FUNDAMENTAL2_CHG  feat_K10_FILING  \
# Date
# 2019-12-24              -0.337975               0.541358                3
# 2019-12-26              -0.408145               0.929980                0
# 2019-12-27               0.162783               0.732749                3
# 2019-12-30              -0.933116               0.980977                0
# 2019-12-31               0.383039               0.336035                1
#
#             feat_SENTIMENT_UP  feat_DIVIDEND
# Date
# 2019-12-24                  0      -0.982111
# 2019-12-26                  1      -2.587859
# 2019-12-27                  1       0.814541
# 2019-12-30                  0      -1.696447
# 2019-12-31                  0       0.176790

# %%
t = '2015-01-01'
data_train = data[:t]
data_test = data[t:]

# %%
for column in data.columns:  
    plt.figure()
    plt.title(column)
    plt.plot(range(0, len(data_train)), data_train[column])
    plt.plot(range(len(data_train), len(data_train) + len(data_test)), data_test[column])
    plt.show()

# %% [markdown]
# # Data Preparation

# %%
from sklearn.preprocessing import StandardScaler

# %%
columns_to_stationarize = ['open', 'high', 'low', 'close', 'volume', 'adj close', 'feat_OBV_volume', 'feat_ATR_close']

# %%
# scaler_y = StandardScaler()
# outputs_train = scaler_y.fit_transform(data_train.close.values.reshape(-1, 1))
# outputs_test = scaler_y.transform(data_test.close.values.reshape(-1, 1))
outputs_train = data_train.close.copy()
outputs_test = data_test.close.copy()

# scaler_x = StandardScaler()
# inputs_train = scaler_x.fit_transform(data_train)
# inputs_test = scaler_x.transform(data_test)

data_train[columns_to_stationarize] = data_train[columns_to_stationarize].pct_change()
data_test[columns_to_stationarize] = data_test[columns_to_stationarize].pct_change()

inputs_train = data_train.replace(np.inf, np.nan).fillna(0.0)
inputs_test = data_test.replace(np.inf, np.nan).fillna(0.0)

# %%
for column in inputs_train.columns:  
    plt.figure()
    plt.title(column)
    plt.plot(range(0, len(data_train)), data_train[column])
    plt.plot(range(len(data_train), len(data_train) + len(data_test)), data_test[column])
    plt.show()

# %%
WINDOW = 14
HORIZON = 1

# %%
def createXY(inputs, outputs):   
    X, Y, P = [], [], []
    for i in range(WINDOW, len(inputs)-1, 1):

        window = inputs[i-WINDOW:i].values
        future = (outputs[i+HORIZON] - outputs[i]) / outputs[i]

        X.append(window)
        Y.append(future)
        P.append(outputs[i])

    X, Y, P = np.array(X), np.array(Y), np.array(P)
    return X, Y, P

# %%
X_train, Y_train, P_train = createXY(inputs_train, outputs_train)
X_test, Y_test, P_test = createXY(inputs_test, outputs_test)

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((3695, 14, 16), (3695,), (1243, 14, 16), (1243,))

# %%
plt.figure()
plt.plot(range(0, len(Y_train)), Y_train)
plt.plot(range(len(Y_train), len(Y_train) + len(Y_test)), Y_test)
plt.show()

# %% [markdown]
# # Modeling

# %%
from keras.models import Model
from keras.layers import Dense, Dropout, GaussianNoise
from keras.layers import Input, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.regularizers import l1, l2 , l1_l2

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.metrics import r2_score, matthews_corrcoef, f1_score, mean_absolute_error
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
def nn(shape):
    main_input = Input(shape=shape, name='main_input')
    x = Flatten()(main_input)
    x = Dense(50, activation='relu')(x)
    x = Dropout(0.25)(x)
    output = Dense(1, activation = "linear")(x)
    
    final_model = Model(inputs=[main_input], outputs=[output])
    return final_model

# %%
model = nn((WINDOW, X_train.shape[2], ))
model.summary()

model.compile(optimizer='adam', loss=['mse'])

checkpointer = ModelCheckpoint(filepath="test.hdf5", verbose=0, save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(X_train, Y_train, 
              validation_data = (X_test, Y_test),
              epochs = 100, 
              batch_size = 16, 
              verbose=True, 
              callbacks=[checkpointer, es],
              shuffle=True
                )

model.load_weights("test.hdf5")
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 14, 16)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 224)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                11250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 11,301
# Trainable params: 11,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3695 samples, validate on 1243 samples
# Epoch 1/100
# 3695/3695 [==============================] - 2s 429us/step - loss: 226.6449 - val_loss: 6.9524
# Epoch 2/100
# 3695/3695 [==============================] - 1s 333us/step - loss: 17.4526 - val_loss: 2.5985
# Epoch 3/100
# 3695/3695 [==============================] - 2s 489us/step - loss: 6.6583 - val_loss: 1.2311
# Epoch 4/100
# 3695/3695 [==============================] - 1s 391us/step - loss: 2.9242 - val_loss: 0.7980
# Epoch 5/100
# 3695/3695 [==============================] - 1s 325us/step - loss: 1.7662 - val_loss: 0.5405
# Epoch 6/100
# 3695/3695 [==============================] - 2s 528us/step - loss: 1.3226 - val_loss: 0.4803
# Epoch 7/100
# 3695/3695 [==============================] - 1s 358us/step - loss: 0.8418 - val_loss: 0.3047
# Epoch 8/100
# 3695/3695 [==============================] - ETA: 0s - loss: 0.626 - 1s 298us/step - loss: 0.6235 - val_loss: 0.2666
# Epoch 9/100
# 3695/3695 [==============================] - 1s 372us/step - loss: 0.3842 - val_loss: 0.1786
# Epoch 10/100
# 3695/3695 [==============================] - 1s 311us/step - loss: 0.4403 - val_loss: 0.1694
# Epoch 11/100
# 3695/3695 [==============================] - 1s 312us/step - loss: 0.2670 - val_loss: 0.1518
# Epoch 12/100
# 3695/3695 [==============================] - 2s 531us/step - loss: 0.1741 - val_loss: 0.1270
# Epoch 13/100
# 3695/3695 [==============================] - 1s 314us/step - loss: 0.2050 - val_loss: 0.1120
# Epoch 14/100
# 3695/3695 [==============================] - 2s 578us/step - loss: 8.5331e-04 - val_loss: 0.0153
# Epoch 44/100
# 3695/3695 [==============================] - 3s 735us/step - loss: 9.1414e-04 - val_loss: 0.0155

# %% [markdown]
# # Evaluation

# %%
pred_test = model.predict(X_test)

# %%
print(mean_absolute_error(Y_test, pred_test), r2_score(Y_test, pred_test))
# Out:
# 0.01907135214472263 -61.317932871932136

# %%
plt.figure(figsize = (15, 5))
plt.plot(Y_test)
plt.plot(pred_test, ls = '--')
plt.show()

# %%
signal = np.sign(pred_test)

# %%
backtest_df = pd.DataFrame(
    {
        'real_change': Y_test.flatten(),
        'signal': signal.flatten()
    }
)

# %%
backtest_df.head(10)
# Out:
#    real_change  signal
# 0     0.001062     1.0
# 1    -0.035013     1.0
# 2     0.056533    -1.0
# 3     0.031134     1.0
# 4    -0.014634    -1.0
# 5     0.012547    -1.0
# 6     0.000169     1.0
# 7     0.007670     1.0
# 8     0.003178     1.0
# 9    -0.008421     1.0

# %%
portfolio = backtest_df['real_change'] * backtest_df['signal']

# %%
plt.figure()
plt.plot(portfolio.cumsum().values)
plt.plot(pd.Series(Y_test.flatten()).cumsum())
plt.show()

# %% [markdown]
# # Checking differentiation

# %%
test_ts = data_train.close.dropna().values

# %%
plt.figure()
plt.plot(test_ts)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import coint

# %%
adf = lambda s: adfuller(s, autolag='AIC')
p_val = lambda s: adfuller(s, autolag='AIC')[1]

# %%
adf(test_ts)
# Out:
# (-13.614519307335193,
#  1.8460072022215217e-25,
#  16,
#  3692,
#  {'1%': -3.4321224410657236,
#   '5%': -2.8623231662354693,
#   '10%': -2.5671868908001723},
#  -16077.561901428817)

# %%
adf(np.diff(test_ts))
# Out:
# (-19.021808812672177,
#  0.0,
#  30,
#  3677,
#  {'1%': -3.432129676641202,
#   '5%': -2.8623263623724924,
#   '10%': -2.567188592313841},
#  -15950.839770285645)

# %%
adf(np.cumsum(test_ts))
# Out:
# (-0.0007559215874931376,
#  0.9584695272107302,
#  17,
#  3691,
#  {'1%': -3.432122921606506,
#   '5%': -2.862323378502749,
#   '10%': -2.567187003803947},
#  -16075.579082807766)

# %%
data = pd.read_csv('aapl_dataset.csv', index_col = 'Date')

# %%
work_ts = data.close.values

# %%
plt.figure()
plt.plot(work_ts)
plt.plot(np.diff(work_ts))
plt.show()

# %%
adf(work_ts)
# Out:
# (2.5089134102656874,
#  0.9990526684630562,
#  29,
#  5001,
#  {'1%': -3.431658270286891,
#   '5%': -2.8621181140235223,
#   '10%': -2.5670777307913744},
#  17355.36805578865)

# %%
adf(np.diff(work_ts))
# Out:
# (-10.313972648012083,
#  3.132186267089252e-18,
#  32,
#  4997,
#  {'1%': -3.431659318070175,
#   '5%': -2.862118576928539,
#   '10%': -2.567077977213785},
#  17351.395427192037)

# %%
np.corrcoef(np.diff(work_ts), work_ts[1:])
# Out:
# array([[1.        , 0.06804097],
#        [0.06804097, 1.        ]])

# %%
np.corrcoef(np.diff(np.diff(work_ts)), work_ts[2:])
# Out:
# array([[1.00000000e+00, 5.36657182e-04],
#        [5.36657182e-04, 1.00000000e+00]])
