# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures

from sklearn import datasets, linear_model

# %%
def f(x):
    return np.sin(x)

# %%
# generate points used to plot
x_plot = np.linspace(0, 10, 100)
x = np.linspace(0, 10, 100)

y = f(x)

# %%
plt.figure()
plt.plot(x, y)
plt.show()

# %%
rng = np.random.RandomState(0)
rng.shuffle(x)

x_train = np.sort(x[:20])
x_test = np.sort(x[20:40])
y_train = f(x_train)
y_test = f(x_test)

# %%
plt.figure()
plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test)
plt.show()

# %%
X_train = x_train[:, np.newaxis]
X_test = x_test[:, np.newaxis]

# %%
pf = PolynomialFeatures(5)
X_train = pf.fit_transform(X_train)
X_test = pf.fit_transform(X_test)

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)
# Out:
# /anaconda2/lib/python2.7/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
plt.figure()
plt.scatter(x_train, y_train)
plt.plot(x_test, y_pred, color = 'red', linestyle = '--')
plt.show()
