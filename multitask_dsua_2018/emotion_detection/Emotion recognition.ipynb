# %%
import matplotlib.pylab as plt
from sklearn.metrics import classification_report

from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, GlobalMaxPooling2D
from keras.optimizers import Adam

import tensorflow as tf
from keras import backend as K
from keras import initializers

import numpy as np
import random
# Out:
# /anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from utils import *
from data import *
# Out:
# /anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
random.seed(42)
np.random.seed(42)
tf.set_random_seed(42)
my_init = initializers.glorot_uniform(seed=42)

# %%
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1,
                              inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# %%
points = load_keypoints_txt_from_folders("./facs_me_db/Landmarks/")
images = load_photos_from_folders("./facs_me_db/cohn-kanade-images/")
labels = load_label_txt_from_folders("./facs_me_db/Emotion/")
labels2 = load_label_txt_from_folders("./facs_me_db/FACS_labels/FACS/")
# Out:
# ['S005', '001', '00000001.png'] Loaded
# ['S005', '001', '00000002.png'] Loaded
# ['S005', '001', '00000003.png'] Loaded
# ['S005', '001', '00000004.png'] Loaded
# ['S005', '001', '00000005.png'] Loaded
# ['S005', '001', '00000006.png'] Loaded
# ['S005', '001', '00000007.png'] Loaded
# ['S005', '001', '00000008.png'] Loaded
# ['S005', '001', '00000009.png'] Loaded
# ['S005', '001', '00000010.png'] Loaded
# ['S005', '001', '00000011.png'] Loaded
# ['S010', '001', '00000001.png'] Loaded
# ['S010', '001', '00000002.png'] Loaded
# ['S010', '001', '00000003.png'] Loaded
# ['S010', '001', '00000004.png'] Loaded
# ['S010', '001', '00000005.png'] Loaded
# ['S010', '001', '00000006.png'] Loaded
# ['S010', '001', '00000007.png'] Loaded
# ['S010', '001', '00000008.png'] Loaded
# ['S010', '001', '00000009.png'] Loaded
# ['S010', '001', '00000010.png'] Loaded
# ['S010', '001', '00000011.png'] Loaded
# ['S010', '001', '00000012.png'] Loaded
# ['S010', '001', '00000013.png'] Loaded
# ['S010', '001', '00000014.png'] Loaded
# ['S010', '002', '00000001.png'] Loaded
# ['S010', '002', '00000002.png'] Loaded
# ['S010', '002', '00000003.png'] Loaded
# ['S010', '002', '00000004.png'] Loaded
# ['S010', '002', '00000005.png'] Loaded
# ['S010', '002', '00000006.png'] Loaded
# ['S010', '002', '00000007.png'] Loaded
# ['S010', '002', '00000008.png'] Loaded
# ['S010', '002', '00000009.png'] Loaded
# ['S010', '002', '00000010.png'] Loaded
# ['S010', '002', '00000011.png'] Loaded
# ['S010', '002', '00000012.png'] Loaded
# ['S010', '002', '00000013.png'] Loaded
# ['S010', '002', '00000014.png'] Loaded
# ['S010', '003', '00000001.png'] Loaded
# ['S010', '003', '00000002.png'] Loaded
# ['S010', '003', '00000003.png'] Loaded
# ['S010', '003', '00000004.png'] Loaded
# ['S010', '003', '00000005.png'] Loaded
# ['S010', '003', '00000006.png'] Loaded
# ['S010', '003', '00000007.png'] Loaded
# ['S010', '003', '00000008.png'] Loaded
# ['S010', '003', '00000009.png'] Loaded
# ['S010', '003', '00000010.png'] Loaded
# ['S010', '003', '00000011.png'] Loaded
# ['S010', '003', '00000012.png'] Loaded
# ['S010', '003', '00000013.png'] Loaded
# ['S010', '003', '00000014.png'] Loaded
# ['S010', '003', '00000015.png'] Loaded
# ['S010', '003', '00000016.png'] Loaded
# ['S010', '003', '00000017.png'] Loaded
# ['S010', '003', '00000018.png'] Loaded
# ['S010', '004', '00000001.png'] Loaded
# ['S010', '004', '00000002.png'] Loaded
# ['S010', '004', '00000003.png'] Loaded
# ['S010', '004', '00000004.png'] Loaded
# ['S010', '004', '00000005.png'] Loaded
# ['S010', '004', '00000006.png'] Loaded
# ['S010', '004', '00000007.png'] Loaded
# ['S010', '004', '00000008.png'] Loaded
# ['S010', '004', '00000009.png'] Loaded
# ['S010', '004', '00000010.png'] Loaded
# ['S010', '004', '00000011.png'] Loaded
# ['S010', '004', '00000012.png'] Loaded
# ['S010', '004', '00000013.png'] Loaded
# ['S010', '004', '00000014.png'] Loaded
# ['S010', '004', '00000015.png'] Loaded
# ['S010', '004', '00000016.png'] Loaded
# ['S010', '004', '00000017.png'] Loaded
# ['S010', '004', '00000018.png'] Loaded
# ['S010', '004', '00000019.png'] Loaded
# ['S010', '005', '00000001.png'] Loaded
# ['S010', '005', '00000002.png'] Loaded
# ['S010', '005', '00000003.png'] Loaded
# ['S010', '005', '00000004.png'] Loaded
# ['S010', '005', '00000005.png'] Loaded
# ['S010', '005', '00000006.png'] Loaded
# ['S010', '005', '00000007.png'] Loaded
# ['S010', '005', '00000008.png'] Loaded
# ['S010', '005', '00000009.png'] Loaded
# ['S010', '005', '00000010.png'] Loaded
# ['S010', '005', '00000011.png'] Loaded
# ['S010', '005', '00000012.png'] Loaded
# ['S010', '005', '00000013.png'] Loaded
# ['S010', '005', '00000014.png'] Loaded
# ['S010', '005', '00000015.png'] Loaded
# ['S010', '005', '00000016.png'] Loaded
# ['S010', '006', '00000001.png'] Loaded
# ['S010', '006', '00000002.png'] Loaded
# ['S010', '006', '00000003.png'] Loaded
# ['S010', '006', '00000004.png'] Loaded
# ['S010', '006', '00000005.png'] Loaded
# ['S010', '006', '00000006.png'] Loaded
# ['S010', '006', '00000007.png'] Loaded
# ['S010', '006', '00000008.png'] Loaded
# ['S010', '006', '00000009.png'] Loaded
# ['S010', '006', '00000010.png'] Loaded
# ['S010', '006', '00000011.png'] Loaded
# ['S010', '006', '00000012.png'] Loaded
# ['S010', '006', '00000013.png'] Loaded
# ['S010', '006', '00000014.png'] Loaded
# ['S010', '006', '00000015.png'] Loaded
# ['S011', '001', '00000001.png'] Loaded
# ['S011', '001', '00000002.png'] Loaded
# ['S011', '001', '00000003.png'] Loaded
# ['S011', '001', '00000004.png'] Loaded
# ['S011', '001', '00000005.png'] Loaded
# ['S011', '001', '00000006.png'] Loaded
# ['S011', '001', '00000007.png'] Loaded
# ['S011', '001', '00000008.png'] Loaded
# ['S011', '001', '00000009.png'] Loaded
# ['S011', '001', '00000010.png'] Loaded
# ['S011', '001', '00000011.png'] Loaded
# ['S011', '001', '00000012.png'] Loaded
# ['S011', '001', '00000013.png'] Loaded
# ['S011', '001', '00000014.png'] Loaded
# ['S011', '001', '00000015.png'] Loaded
# ['S011', '001', '00000016.png'] Loaded
# ['S011', '002', '00000001.png'] Loaded
# ['S011', '002', '00000002.png'] Loaded
# ['S011', '002', '00000003.png'] Loaded
# ['S011', '002', '00000004.png'] Loaded
# ['S011', '002', '00000005.png'] Loaded
# ['S011', '002', '00000006.png'] Loaded
# ['S011', '002', '00000007.png'] Loaded
# ['S011', '002', '00000008.png'] Loaded
# ['S011', '002', '00000009.png'] Loaded
# ['S011', '002', '00000010.png'] Loaded
# ['S011', '002', '00000011.png'] Loaded
# ['S011', '002', '00000012.png'] Loaded
# ['S011', '002', '00000013.png'] Loaded
# ['S011', '002', '00000014.png'] Loaded
# ['S011', '002', '00000015.png'] Loaded
# ['S011', '002', '00000016.png'] Loaded
# ['S011', '002', '00000017.png'] Loaded
# ['S011', '002', '00000018.png'] Loaded
# ['S011', '002', '00000019.png'] Loaded
# ['S011', '002', '00000020.png'] Loaded
# ['S011', '002', '00000021.png'] Loaded
# ['S011', '002', '00000022.png'] Loaded
# ['S011', '003', '00000001.png'] Loaded
# ['S011', '003', '00000002.png'] Loaded
# ['S011', '003', '00000003.png'] Loaded
# ['S011', '003', '00000004.png'] Loaded
# ['S011', '003', '00000005.png'] Loaded
# ['S011', '003', '00000006.png'] Loaded
# ['S011', '003', '00000007.png'] Loaded
# ['S011', '003', '00000008.png'] Loaded
# ['S011', '003', '00000009.png'] Loaded
# ['S011', '003', '00000010.png'] Loaded
# ['S011', '003', '00000011.png'] Loaded
# ['S011', '003', '00000012.png'] Loaded
# ['S011', '003', '00000013.png'] Loaded
# ['S011', '003', '00000014.png'] Loaded
# ['S011', '004', '00000001.png'] Loaded
# ['S011', '004', '00000002.png'] Loaded
# ['S011', '004', '00000003.png'] Loaded
# ['S011', '004', '00000004.png'] Loaded
# ['S011', '004', '00000005.png'] Loaded
# ['S011', '004', '00000006.png'] Loaded
# ['S011', '004', '00000007.png'] Loaded
# ['S011', '004', '00000008.png'] Loaded
# ['S011', '004', '00000009.png'] Loaded
# ['S011', '004', '00000010.png'] Loaded
# ['S011', '004', '00000011.png'] Loaded
# ['S011', '004', '00000012.png'] Loaded
# ['S011', '004', '00000013.png'] Loaded
# ['S011', '004', '00000014.png'] Loaded
# ['S011', '004', '00000015.png'] Loaded
# ['S011', '004', '00000016.png'] Loaded
# ['S011', '004', '00000017.png'] Loaded
# ['S011', '004', '00000018.png'] Loaded
# ['S011', '004', '00000019.png'] Loaded
# ['S011', '004', '00000020.png'] Loaded
# ['S011', '004', '00000021.png'] Loaded
# ['S011', '005', '00000001.png'] Loaded
# ['S011', '005', '00000002.png'] Loaded
# ['S011', '005', '00000003.png'] Loaded
# ['S011', '005', '00000004.png'] Loaded
# ['S011', '005', '00000005.png'] Loaded
# ['S011', '005', '00000006.png'] Loaded
# ['S011', '005', '00000007.png'] Loaded
# ['S011', '005', '00000008.png'] Loaded
# ['S011', '005', '00000009.png'] Loaded
# ['S011', '005', '00000010.png'] Loaded
# ['S011', '005', '00000011.png'] Loaded
# ['S011', '005', '00000012.png'] Loaded
# ['S011', '005', '00000013.png'] Loaded
# ['S011', '005', '00000014.png'] Loaded
# ['S011', '005', '00000015.png'] Loaded
# ['S011', '005', '00000016.png'] Loaded
# ['S011', '005', '00000017.png'] Loaded
# ['S011', '005', '00000018.png'] Loaded
# ['S011', '005', '00000019.png'] Loaded
# ['S011', '005', '00000020.png'] Loaded
# ['S011', '006', '00000001.png'] Loaded
# ['S011', '006', '00000002.png'] Loaded
# ['S011', '006', '00000003.png'] Loaded
# ['S011', '006', '00000004.png'] Loaded
# ['S011', '006', '00000005.png'] Loaded
# ['S011', '006', '00000006.png'] Loaded
# ['S011', '006', '00000007.png'] Loaded
# ['S011', '006', '00000008.png'] Loaded
# ['S011', '006', '00000009.png'] Loaded
# ['S011', '006', '00000010.png'] Loaded
# ['S011', '006', '00000011.png'] Loaded
# ['S011', '006', '00000012.png'] Loaded
# ['S011', '006', '00000013.png'] Loaded
# ['S014', '001', '00000001.png'] Loaded
# ['S014', '001', '00000002.png'] Loaded
# ['S014', '001', '00000003.png'] Loaded
# ['S014', '001', '00000004.png'] Loaded
# ['S014', '001', '00000005.png'] Loaded
# ['S014', '001', '00000006.png'] Loaded
# ['S014', '001', '00000007.png'] Loaded
# ['S014', '001', '00000008.png'] Loaded
# ['S014', '001', '00000009.png'] Loaded
# ['S014', '001', '00000010.png'] Loaded
# ['S014', '001', '00000011.png'] Loaded
# ['S014', '001', '00000012.png'] Loaded
# ['S014', '001', '00000013.png'] Loaded
# ['S014', '001', '00000014.png'] Loaded
# ['S014', '001', '00000015.png'] Loaded
# ['S014', '001', '00000016.png'] Loaded
# ['S014', '001', '00000017.png'] Loaded
# ['S014', '001', '00000018.png'] Loaded
# ['S014', '001', '00000019.png'] Loaded
# ['S014', '001', '00000020.png'] Loaded
# ['S014', '001', '00000021.png'] Loaded
# ['S014', '001', '00000022.png'] Loaded
# ['S014', '001', '00000023.png'] Loaded
# ['S014', '001', '00000024.png'] Loaded
# ['S014', '001', '00000025.png'] Loaded
# ['S014', '001', '00000026.png'] Loaded
# ['S014', '001', '00000027.png'] Loaded
# ['S014', '001', '00000028.png'] Loaded
# ['S014', '001', '00000029.png'] Loaded
# ['S014', '002', '00000001.png'] Loaded
# ['S014', '002', '00000002.png'] Loaded
# ['S014', '002', '00000003.png'] Loaded
# ['S014', '002', '00000004.png'] Loaded
# ['S014', '002', '00000005.png'] Loaded
# ['S014', '002', '00000006.png'] Loaded
# ['S014', '002', '00000007.png'] Loaded
# ['S014', '002', '00000008.png'] Loaded
# ['S014', '002', '00000009.png'] Loaded
# ['S014', '002', '00000010.png'] Loaded
# ['S014', '002', '00000011.png'] Loaded
# ['S014', '002', '00000012.png'] Loaded
# ['S014', '002', '00000013.png'] Loaded
# ['S014', '002', '00000014.png'] Loaded
# ['S014', '002', '00000015.png'] Loaded
# ['S014', '002', '00000016.png'] Loaded
# ['S014', '003', '00000001.png'] Loaded
# ['S014', '003', '00000002.png'] Loaded
# ['S014', '003', '00000003.png'] Loaded
# ['S014', '003', '00000004.png'] Loaded
# ['S014', '003', '00000005.png'] Loaded
# ['S014', '003', '00000006.png'] Loaded
# ['S014', '003', '00000007.png'] Loaded
# ['S014', '003', '00000008.png'] Loaded
# ['S014', '003', '00000009.png'] Loaded
# ['S014', '003', '00000010.png'] Loaded
# ['S014', '003', '00000011.png'] Loaded
# ['S014', '003', '00000012.png'] Loaded
# ['S014', '003', '00000013.png'] Loaded
# ['S014', '003', '00000014.png'] Loaded
# ['S014', '003', '00000015.png'] Loaded
# ['S014', '003', '00000016.png'] Loaded
# ['S014', '003', '00000017.png'] Loaded
# ['S014', '003', '00000018.png'] Loaded
# ['S014', '003', '00000019.png'] Loaded
# ['S014', '003', '00000020.png'] Loaded
# ['S014', '003', '00000021.png'] Loaded
# ['S014', '003', '00000022.png'] Loaded
# ['S014', '003', '00000023.png'] Loaded
# ['S014', '003', '00000024.png'] Loaded
# ['S014', '003', '00000025.png'] Loaded
# ['S014', '003', '00000026.png'] Loaded
# ['S014', '003', '00000027.png'] Loaded
# ['S014', '003', '00000028.png'] Loaded
# ['S014', '003', '00000029.png'] Loaded
# ['S014', '003', '00000030.png'] Loaded
# ['S014', '004', '00000001.png'] Loaded
# ['S014', '004', '00000002.png'] Loaded
# ['S014', '004', '00000003.png'] Loaded
# ['S014', '004', '00000004.png'] Loaded
# ['S014', '004', '00000005.png'] Loaded
# ['S014', '004', '00000006.png'] Loaded
# ['S014', '004', '00000007.png'] Loaded
# ['S014', '004', '00000008.png'] Loaded
# ['S014', '004', '00000009.png'] Loaded
# ['S014', '004', '00000010.png'] Loaded
# ['S014', '004', '00000011.png'] Loaded
# ['S014', '004', '00000012.png'] Loaded
# ['S014', '004', '00000013.png'] Loaded
# ['S014', '004', '00000014.png'] Loaded
# ['S014', '004', '00000015.png'] Loaded
# ['S014', '004', '00000016.png'] Loaded
# ['S014', '004', '00000017.png'] Loaded
# ['S014', '004', '00000018.png'] Loaded
# ['S014', '004', '00000019.png'] Loaded
# ['S014', '005', '00000001.png'] Loaded
# ['S014', '005', '00000002.png'] Loaded
# ['S014', '005', '00000003.png'] Loaded
# ['S014', '005', '00000004.png'] Loaded
# ['S014', '005', '00000005.png'] Loaded
# ['S014', '005', '00000006.png'] Loaded
# ['S014', '005', '00000007.png'] Loaded
# ['S014', '005', '00000008.png'] Loaded
# ['S014', '005', '00000009.png'] Loaded
# ['S014', '005', '00000010.png'] Loaded
# ['S014', '005', '00000011.png'] Loaded
# ['S014', '005', '00000012.png'] Loaded
# ['S014', '005', '00000013.png'] Loaded
# ['S014', '005', '00000014.png'] Loaded
# ['S014', '005', '00000015.png'] Loaded
# ['S014', '005', '00000016.png'] Loaded
# ['S014', '005', '00000017.png'] Loaded
# ['S022', '001', '00000001.png'] Loaded
# ['S022', '001', '00000002.png'] Loaded
# ['S022', '001', '00000003.png'] Loaded
# ['S022', '001', '00000004.png'] Loaded
# ['S022', '001', '00000005.png'] Loaded
# ['S022', '001', '00000006.png'] Loaded
# ['S022', '001', '00000007.png'] Loaded
# ['S022', '001', '00000008.png'] Loaded
# ['S022', '001', '00000009.png'] Loaded
# ['S022', '001', '00000010.png'] Loaded
# ['S022', '001', '00000011.png'] Loaded
# ['S022', '001', '00000012.png'] Loaded
# ['S022', '001', '00000013.png'] Loaded
# ['S022', '001', '00000014.png'] Loaded
# ['S022', '001', '00000015.png'] Loaded
# ['S022', '001', '00000016.png'] Loaded
# ['S022', '001', '00000017.png'] Loaded
# ['S022', '001', '00000018.png'] Loaded
# ['S022', '001', '00000019.png'] Loaded
# ['S022', '001', '00000020.png'] Loaded
# ['S022', '001', '00000021.png'] Loaded
# ['S022', '001', '00000022.png'] Loaded
# ['S022', '001', '00000023.png'] Loaded
# ['S022', '001', '00000024.png'] Loaded
# ['S022', '001', '00000025.png'] Loaded
# ['S022', '001', '00000026.png'] Loaded
# ['S022', '001', '00000027.png'] Loaded
# ['S022', '001', '00000028.png'] Loaded
# ['S022', '001', '00000029.png'] Loaded
# ['S022', '001', '00000030.png'] Loaded
# ['S022', '002', '00000001.png'] Loaded
# ['S022', '002', '00000002.png'] Loaded
# ['S022', '002', '00000003.png'] Loaded
# ['S022', '002', '00000004.png'] Loaded
# ['S022', '002', '00000005.png'] Loaded
# ['S022', '002', '00000006.png'] Loaded
# ['S022', '002', '00000007.png'] Loaded
# ['S022', '002', '00000008.png'] Loaded
# ['S022', '002', '00000009.png'] Loaded
# ['S022', '002', '00000010.png'] Loaded
# ['S022', '002', '00000011.png'] Loaded
# ['S022', '002', '00000012.png'] Loaded
# ['S022', '002', '00000013.png'] Loaded
# ['S022', '002', '00000014.png'] Loaded
# ['S022', '002', '00000015.png'] Loaded
# ['S022', '002', '00000016.png'] Loaded
# ['S022', '002', '00000017.png'] Loaded
# ['S022', '003', '00000001.png'] Loaded
# ['S022', '003', '00000002.png'] Loaded
# ['S022', '003', '00000003.png'] Loaded
# ['S022', '003', '00000004.png'] Loaded
# ['S022', '003', '00000005.png'] Loaded
# ['S022', '003', '00000006.png'] Loaded
# ['S022', '003', '00000007.png'] Loaded
# ['S022', '003', '00000008.png'] Loaded
# ['S022', '003', '00000009.png'] Loaded
# ['S022', '003', '00000010.png'] Loaded
# ['S022', '003', '00000011.png'] Loaded
# ['S022', '003', '00000012.png'] Loaded
# ['S022', '003', '00000013.png'] Loaded
# ['S022', '003', '00000014.png'] Loaded
# ['S022', '003', '00000015.png'] Loaded
# ['S022', '003', '00000016.png'] Loaded
# ['S022', '003', '00000017.png'] Loaded
# ['S022', '003', '00000018.png'] Loaded
# ['S022', '003', '00000019.png'] Loaded
# ['S022', '003', '00000020.png'] Loaded
# ['S022', '003', '00000021.png'] Loaded
# ['S022', '003', '00000022.png'] Loaded
# ['S022', '003', '00000023.png'] Loaded
# ['S022', '003', '00000024.png'] Loaded
# ['S022', '003', '00000025.png'] Loaded
# ['S022', '003', '00000026.png'] Loaded
# ['S022', '003', '00000027.png'] Loaded
# ['S022', '003', '00000028.png'] Loaded
# ['S022', '003', '00000029.png'] Loaded
# ['S022', '003', '00000030.png'] Loaded
# ['S022', '003', '00000031.png'] Loaded
# ['S022', '003', '00000032.png'] Loaded
# ['S022', '003', '00000033.png'] Loaded
# ['S022', '004', '00000001.png'] Loaded
# ['S022', '004', '00000002.png'] Loaded
# ['S022', '004', '00000003.png'] Loaded
# ['S022', '004', '00000004.png'] Loaded
# ['S022', '004', '00000005.png'] Loaded
# ['S022', '004', '00000006.png'] Loaded
# ['S022', '004', '00000007.png'] Loaded
# ['S022', '004', '00000008.png'] Loaded
# ['S022', '004', '00000009.png'] Loaded
# ['S022', '004', '00000010.png'] Loaded
# ['S022', '004', '00000011.png'] Loaded
# ['S022', '004', '00000012.png'] Loaded
# ['S022', '004', '00000013.png'] Loaded
# ['S022', '004', '00000014.png'] Loaded
# ['S022', '004', '00000015.png'] Loaded
# ['S022', '004', '00000016.png'] Loaded
# ['S022', '004', '00000017.png'] Loaded
# ['S022', '004', '00000018.png'] Loaded
# ['S022', '004', '00000019.png'] Loaded
# ['S022', '004', '00000020.png'] Loaded
# ['S022', '004', '00000021.png'] Loaded
# ['S022', '004', '00000022.png'] Loaded
# ['S022', '004', '00000023.png'] Loaded
# ['S022', '005', '00000001.png'] Loaded
# ['S022', '005', '00000002.png'] Loaded
# ['S022', '005', '00000003.png'] Loaded
# ['S022', '005', '00000004.png'] Loaded
# ['S022', '005', '00000005.png'] Loaded
# ['S022', '005', '00000006.png'] Loaded
# ['S022', '005', '00000007.png'] Loaded
# ['S022', '005', '00000008.png'] Loaded
# ['S022', '005', '00000009.png'] Loaded
# ['S022', '005', '00000010.png'] Loaded
# ['S022', '005', '00000011.png'] Loaded
# ['S022', '005', '00000012.png'] Loaded
# ['S022', '005', '00000013.png'] Loaded
# ['S022', '005', '00000014.png'] Loaded
# ['S022', '005', '00000015.png'] Loaded
# ['S022', '005', '00000016.png'] Loaded
# ['S022', '005', '00000017.png'] Loaded
# ['S022', '005', '00000018.png'] Loaded
# ['S022', '005', '00000019.png'] Loaded
# ['S022', '005', '00000020.png'] Loaded
# ['S022', '005', '00000021.png'] Loaded
# ['S022', '005', '00000022.png'] Loaded
# ['S022', '005', '00000023.png'] Loaded
# ['S022', '005', '00000024.png'] Loaded
# ['S022', '005', '00000025.png'] Loaded
# ['S022', '005', '00000026.png'] Loaded
# ['S022', '005', '00000027.png'] Loaded
# ['S022', '005', '00000028.png'] Loaded
# ['S022', '005', '00000029.png'] Loaded
# ['S022', '005', '00000030.png'] Loaded
# ['S022', '005', '00000031.png'] Loaded
# ['S022', '005', '00000032.png'] Loaded
# ['S022', '006', '00000001.png'] Loaded
# ['S022', '006', '00000002.png'] Loaded
# ['S022', '006', '00000003.png'] Loaded
# ['S022', '006', '00000004.png'] Loaded
# ['S022', '006', '00000005.png'] Loaded
# ['S022', '006', '00000006.png'] Loaded
# ['S022', '006', '00000007.png'] Loaded
# ['S022', '006', '00000008.png'] Loaded
# ['S022', '006', '00000009.png'] Loaded
# ['S022', '006', '00000010.png'] Loaded
# ['S022', '006', '00000011.png'] Loaded
# ['S022', '006', '00000012.png'] Loaded
# ['S022', '006', '00000013.png'] Loaded
# ['S022', '006', '00000014.png'] Loaded
# ['S022', '006', '00000015.png'] Loaded
# ['S022', '006', '00000016.png'] Loaded
# ['S022', '006', '00000017.png'] Loaded
# ['S026', '001', '00000001.png'] Loaded
# ['S026', '001', '00000002.png'] Loaded
# ['S026', '001', '00000003.png'] Loaded
# ['S026', '001', '00000004.png'] Loaded
# ['S026', '001', '00000005.png'] Loaded
# ['S026', '001', '00000006.png'] Loaded
# ['S026', '001', '00000007.png'] Loaded
# ['S026', '001', '00000008.png'] Loaded
# ['S026', '001', '00000009.png'] Loaded
# ['S026', '001', '00000010.png'] Loaded
# ['S026', '001', '00000011.png'] Loaded
# ['S026', '001', '00000012.png'] Loaded
# ['S026', '001', '00000013.png'] Loaded
# ['S026', '001', '00000014.png'] Loaded
# ['S026', '001', '00000015.png'] Loaded
# ['S026', '002', '00000001.png'] Loaded
# ['S026', '002', '00000002.png'] Loaded
# ['S026', '002', '00000003.png'] Loaded
# ['S026', '002', '00000004.png'] Loaded
# ['S026', '002', '00000005.png'] Loaded
# ['S026', '002', '00000006.png'] Loaded
# ['S026', '002', '00000007.png'] Loaded
# ['S026', '002', '00000008.png'] Loaded
# ['S026', '002', '00000009.png'] Loaded
# ['S026', '002', '00000010.png'] Loaded
# ['S026', '002', '00000011.png'] Loaded
# ['S026', '002', '00000012.png'] Loaded
# ['S026', '002', '00000013.png'] Loaded
# ['S026', '002', '00000014.png'] Loaded
# ['S026', '002', '00000015.png'] Loaded
# ['S026', '002', '00000016.png'] Loaded
# ['S026', '003', '00000001.png'] Loaded
# ['S026', '003', '00000002.png'] Loaded
# ['S026', '003', '00000003.png'] Loaded
# ['S026', '003', '00000004.png'] Loaded
# ['S026', '003', '00000005.png'] Loaded
# ['S026', '003', '00000006.png'] Loaded
# ['S026', '003', '00000007.png'] Loaded
# ['S026', '003', '00000008.png'] Loaded
# ['S026', '003', '00000009.png'] Loaded
# ['S026', '003', '00000010.png'] Loaded
# ['S026', '003', '00000011.png'] Loaded
# ['S026', '003', '00000012.png'] Loaded
# ['S026', '003', '00000013.png'] Loaded
# ['S026', '003', '00000014.png'] Loaded
# ['S026', '003', '00000015.png'] Loaded
# ['S026', '004', '00000001.png'] Loaded
# ['S026', '004', '00000002.png'] Loaded
# ['S026', '004', '00000003.png'] Loaded
# ['S026', '004', '00000004.png'] Loaded
# ['S026', '004', '00000005.png'] Loaded
# ['S026', '004', '00000006.png'] Loaded
# ['S026', '004', '00000007.png'] Loaded
# ['S026', '004', '00000008.png'] Loaded
# ['S026', '004', '00000009.png'] Loaded
# ['S026', '004', '00000010.png'] Loaded
# ['S026', '004', '00000011.png'] Loaded
# ['S026', '004', '00000012.png'] Loaded
# ['S026', '005', '00000001.png'] Loaded
# ['S026', '005', '00000002.png'] Loaded
# ['S026', '005', '00000003.png'] Loaded
# ['S026', '005', '00000004.png'] Loaded
# ['S026', '005', '00000005.png'] Loaded
# ['S026', '005', '00000006.png'] Loaded
# ['S026', '005', '00000007.png'] Loaded
# ['S026', '005', '00000008.png'] Loaded
# ['S026', '005', '00000009.png'] Loaded
# ['S026', '005', '00000010.png'] Loaded
# ['S026', '005', '00000011.png'] Loaded
# ['S026', '005', '00000012.png'] Loaded
# ['S026', '005', '00000013.png'] Loaded
# ['S026', '005', '00000014.png'] Loaded
# ['S026', '006', '00000001.png'] Loaded
# ['S026', '006', '00000002.png'] Loaded
# ['S026', '006', '00000003.png'] Loaded
# ['S026', '006', '00000004.png'] Loaded
# ['S026', '006', '00000005.png'] Loaded
# ['S026', '006', '00000006.png'] Loaded
# ['S026', '006', '00000007.png'] Loaded
# ['S026', '006', '00000008.png'] Loaded
# ['S026', '006', '00000009.png'] Loaded
# ['S026', '006', '00000010.png'] Loaded
# ['S026', '006', '00000011.png'] Loaded
# ['S026', '006', '00000012.png'] Loaded
# ['S026', '006', '00000013.png'] Loaded
# ['S028', '001', '00000001.png'] Loaded
# ['S028', '001', '00000002.png'] Loaded
# ['S028', '001', '00000003.png'] Loaded
# ['S028', '001', '00000004.png'] Loaded
# ['S028', '001', '00000005.png'] Loaded
# ['S028', '001', '00000006.png'] Loaded
# ['S028', '001', '00000007.png'] Loaded
# ['S028', '001', '00000008.png'] Loaded
# ['S028', '001', '00000009.png'] Loaded
# ['S028', '001', '00000010.png'] Loaded
# ['S028', '001', '00000011.png'] Loaded
# ['S028', '001', '00000012.png'] Loaded
# ['S028', '001', '00000013.png'] Loaded
# ['S028', '001', '00000014.png'] Loaded
# ['S028', '001', '00000015.png'] Loaded
# ['S028', '001', '00000016.png'] Loaded
# ['S028', '001', '00000017.png'] Loaded
# ['S028', '001', '00000018.png'] Loaded
# ['S028', '001', '00000019.png'] Loaded
# ['S028', '001', '00000020.png'] Loaded
# ['S028', '001', '00000021.png'] Loaded
# ['S028', '001', '00000022.png'] Loaded
# ['S028', '001', '00000023.png'] Loaded
# ['S028', '001', '00000024.png'] Loaded
# ['S029', '001', '00000001.png'] Loaded
# ['S029', '001', '00000002.png'] Loaded
# ['S029', '001', '00000003.png'] Loaded
# ['S029', '001', '00000004.png'] Loaded
# ['S029', '001', '00000005.png'] Loaded
# ['S029', '001', '00000006.png'] Loaded
# ['S029', '001', '00000007.png'] Loaded
# ['S029', '001', '00000008.png'] Loaded
# ['S029', '001', '00000009.png'] Loaded
# ['S029', '001', '00000010.png'] Loaded
# ['S029', '001', '00000011.png'] Loaded
# ['S029', '001', '00000012.png'] Loaded
# ['S029', '001', '00000013.png'] Loaded
# ['S029', '001', '00000014.png'] Loaded
# ['S029', '001', '00000015.png'] Loaded
# ['S029', '001', '00000016.png'] Loaded
# ['S029', '001', '00000017.png'] Loaded
# ['S029', '001', '00000018.png'] Loaded
# ['S029', '001', '00000019.png'] Loaded
# ['S032', '001', '00000001.png'] Loaded
# ['S032', '001', '00000002.png'] Loaded
# ['S032', '001', '00000003.png'] Loaded
# ['S032', '001', '00000004.png'] Loaded
# ['S032', '001', '00000005.png'] Loaded
# ['S032', '001', '00000006.png'] Loaded
# ['S032', '001', '00000007.png'] Loaded
# ['S032', '001', '00000008.png'] Loaded
# ['S032', '001', '00000009.png'] Loaded
# ['S032', '001', '00000010.png'] Loaded
# ['S032', '001', '00000011.png'] Loaded
# ['S032', '001', '00000012.png'] Loaded
# ['S032', '001', '00000013.png'] Loaded
# ['S032', '001', '00000014.png'] Loaded
# ['S032', '001', '00000015.png'] Loaded
# ['S032', '001', '00000016.png'] Loaded
# ['S032', '001', '00000017.png'] Loaded
# ['S032', '001', '00000018.png'] Loaded
# ['S032', '001', '00000019.png'] Loaded
# ['S032', '001', '00000020.png'] Loaded
# ['S032', '001', '00000021.png'] Loaded
# ['S032', '001', '00000022.png'] Loaded
# ['S032', '002', '00000001.png'] Loaded
# ['S032', '002', '00000002.png'] Loaded
# ['S032', '002', '00000003.png'] Loaded
# ['S032', '002', '00000004.png'] Loaded
# ['S032', '002', '00000005.png'] Loaded
# ['S032', '002', '00000006.png'] Loaded
# ['S032', '002', '00000007.png'] Loaded
# ['S032', '002', '00000008.png'] Loaded
# ['S032', '002', '00000009.png'] Loaded
# ['S032', '002', '00000010.png'] Loaded
# ['S032', '002', '00000011.png'] Loaded
# ['S032', '002', '00000012.png'] Loaded
# ['S032', '002', '00000013.png'] Loaded
# ['S032', '002', '00000014.png'] Loaded
# ['S032', '002', '00000015.png'] Loaded
# ['S032', '002', '00000016.png'] Loaded
# ['S032', '002', '00000017.png'] Loaded
# ['S032', '002', '00000018.png'] Loaded
# ['S032', '002', '00000019.png'] Loaded
# ['S032', '002', '00000020.png'] Loaded
# ['S032', '002', '00000021.png'] Loaded
# ['S032', '003', '00000001.png'] Loaded
# ['S032', '003', '00000002.png'] Loaded
# ['S032', '003', '00000003.png'] Loaded
# ['S032', '003', '00000004.png'] Loaded
# ['S032', '003', '00000005.png'] Loaded
# ['S032', '003', '00000006.png'] Loaded
# ['S032', '003', '00000007.png'] Loaded
# ['S032', '003', '00000008.png'] Loaded
# ['S032', '003', '00000009.png'] Loaded
# ['S032', '003', '00000010.png'] Loaded
# ['S032', '003', '00000011.png'] Loaded
# ['S032', '003', '00000012.png'] Loaded
# ['S032', '003', '00000013.png'] Loaded
# ['S032', '003', '00000014.png'] Loaded
# ['S032', '003', '00000015.png'] Loaded
# ['S032', '003', '00000016.png'] Loaded
# ['S032', '003', '00000017.png'] Loaded
# ['S032', '004', '00000001.png'] Loaded
# ['S032', '004', '00000002.png'] Loaded
# ['S032', '004', '00000003.png'] Loaded
# ['S032', '004', '00000004.png'] Loaded
# ['S032', '004', '00000005.png'] Loaded
# ['S032', '004', '00000006.png'] Loaded
# ['S032', '004', '00000007.png'] Loaded
# ['S032', '004', '00000008.png'] Loaded
# ['S032', '004', '00000009.png'] Loaded
# ['S032', '004', '00000010.png'] Loaded
# ['S032', '004', '00000011.png'] Loaded
# ['S032', '004', '00000012.png'] Loaded
# ['S032', '004', '00000013.png'] Loaded
# ['S032', '004', '00000014.png'] Loaded
# ['S032', '005', '00000001.png'] Loaded
# ['S032', '005', '00000002.png'] Loaded
# ['S032', '005', '00000003.png'] Loaded
# ['S032', '005', '00000004.png'] Loaded
# ['S032', '005', '00000005.png'] Loaded
# ['S032', '005', '00000006.png'] Loaded
# ['S032', '005', '00000007.png'] Loaded
# ['S032', '005', '00000008.png'] Loaded
# ['S032', '005', '00000009.png'] Loaded
# ['S032', '005', '00000010.png'] Loaded
# ['S032', '005', '00000011.png'] Loaded
# ['S032', '005', '00000012.png'] Loaded
# ['S032', '005', '00000013.png'] Loaded
# ['S032', '005', '00000014.png'] Loaded
# ['S032', '005', '00000015.png'] Loaded
# ['S032', '005', '00000016.png'] Loaded
# ['S032', '006', '00000001.png'] Loaded
# ['S032', '006', '00000002.png'] Loaded
# ['S032', '006', '00000003.png'] Loaded
# ['S032', '006', '00000004.png'] Loaded
# ['S032', '006', '00000005.png'] Loaded
# ['S032', '006', '00000006.png'] Loaded
# ['S032', '006', '00000007.png'] Loaded
# ['S032', '006', '00000008.png'] Loaded
# ['S032', '006', '00000009.png'] Loaded
# ['S032', '006', '00000010.png'] Loaded
# ['S032', '006', '00000011.png'] Loaded
# ['S032', '006', '00000012.png'] Loaded
# ['S032', '006', '00000013.png'] Loaded
# ['S032', '006', '00000014.png'] Loaded
# ['S032', '006', '00000015.png'] Loaded
# ['S032', '006', '00000016.png'] Loaded
# ['S034', '001', '00000001.png'] Loaded
# ['S034', '001', '00000002.png'] Loaded
# ['S034', '001', '00000003.png'] Loaded
# ['S034', '001', '00000004.png'] Loaded
# ['S034', '001', '00000005.png'] Loaded
# ['S034', '001', '00000006.png'] Loaded
# ['S034', '001', '00000007.png'] Loaded
# ['S034', '001', '00000008.png'] Loaded
# ['S034', '001', '00000009.png'] Loaded
# ['S034', '001', '00000010.png'] Loaded
# ['S034', '001', '00000011.png'] Loaded
# ['S034', '001', '00000012.png'] Loaded
# ['S034', '001', '00000013.png'] Loaded
# ['S034', '001', '00000014.png'] Loaded
# ['S034', '001', '00000015.png'] Loaded
# ['S034', '001', '00000016.png'] Loaded
# ['S034', '001', '00000017.png'] Loaded
# ['S034', '001', '00000018.png'] Loaded
# ['S034', '001', '00000019.png'] Loaded
# ['S034', '001', '00000020.png'] Loaded
# ['S034', '001', '00000021.png'] Loaded
# ['S034', '001', '00000022.png'] Loaded
# ['S034', '001', '00000023.png'] Loaded
# ['S034', '001', '00000024.png'] Loaded
# ['S034', '001', '00000025.png'] Loaded
# ['S034', '001', '00000026.png'] Loaded
# ['S034', '001', '00000027.png'] Loaded
# ['S034', '001', '00000028.png'] Loaded
# ['S034', '001', '00000029.png'] Loaded
# ['S034', '002', '00000001.png'] Loaded
# ['S034', '002', '00000002.png'] Loaded
# ['S034', '002', '00000003.png'] Loaded
# ['S034', '002', '00000004.png'] Loaded
# ['S034', '002', '00000005.png'] Loaded
# ['S034', '002', '00000006.png'] Loaded
# ['S034', '002', '00000007.png'] Loaded
# ['S034', '002', '00000008.png'] Loaded
# ['S034', '002', '00000009.png'] Loaded
# ['S034', '002', '00000010.png'] Loaded
# ['S034', '002', '00000011.png'] Loaded
# ['S034', '002', '00000012.png'] Loaded
# ['S034', '002', '00000013.png'] Loaded
# ['S034', '002', '00000014.png'] Loaded
# ['S034', '002', '00000015.png'] Loaded
# ['S034', '002', '00000016.png'] Loaded
# ['S034', '002', '00000017.png'] Loaded
# ['S034', '002', '00000018.png'] Loaded
# ['S034', '002', '00000019.png'] Loaded
# ['S034', '002', '00000020.png'] Loaded
# ['S034', '002', '00000021.png'] Loaded
# ['S034', '002', '00000022.png'] Loaded
# ['S034', '002', '00000023.png'] Loaded
# ['S034', '002', '00000024.png'] Loaded
# ['S034', '002', '00000025.png'] Loaded
# ['S034', '002', '00000026.png'] Loaded
# ['S034', '002', '00000027.png'] Loaded
# ['S034', '002', '00000028.png'] Loaded
# ['S034', '002', '00000029.png'] Loaded
# ['S034', '002', '00000030.png'] Loaded
# ['S034', '002', '00000031.png'] Loaded
# ['S034', '002', '00000032.png'] Loaded
# ['S034', '002', '00000033.png'] Loaded
# ['S034', '003', '00000001.png'] Loaded
# ['S034', '003', '00000002.png'] Loaded
# ['S034', '003', '00000003.png'] Loaded
# ['S034', '003', '00000004.png'] Loaded
# ['S034', '003', '00000005.png'] Loaded
# ['S034', '003', '00000006.png'] Loaded
# ['S034', '003', '00000007.png'] Loaded
# ['S034', '003', '00000008.png'] Loaded
# ['S034', '003', '00000009.png'] Loaded
# ['S034', '003', '00000010.png'] Loaded
# ['S034', '003', '00000011.png'] Loaded
# ['S034', '003', '00000012.png'] Loaded
# ['S034', '003', '00000013.png'] Loaded
# ['S034', '003', '00000014.png'] Loaded
# ['S034', '003', '00000015.png'] Loaded
# ['S034', '003', '00000016.png'] Loaded
# ['S034', '003', '00000017.png'] Loaded
# ['S034', '003', '00000018.png'] Loaded
# ['S034', '003', '00000019.png'] Loaded
# ['S034', '003', '00000020.png'] Loaded
# ['S034', '003', '00000021.png'] Loaded
# ['S034', '003', '00000022.png'] Loaded
# ['S034', '003', '00000023.png'] Loaded
# ['S034', '003', '00000024.png'] Loaded
# ['S034', '003', '00000025.png'] Loaded
# ['S034', '003', '00000026.png'] Loaded
# ['S034', '003', '00000027.png'] Loaded
# ['S034', '004', '00000001.png'] Loaded
# ['S034', '004', '00000002.png'] Loaded
# ['S034', '004', '00000003.png'] Loaded
# ['S034', '004', '00000004.png'] Loaded
# ['S034', '004', '00000005.png'] Loaded
# ['S034', '004', '00000006.png'] Loaded
# ['S034', '004', '00000007.png'] Loaded
# ['S034', '004', '00000008.png'] Loaded
# ['S034', '004', '00000009.png'] Loaded
# ['S034', '004', '00000010.png'] Loaded
# ['S034', '004', '00000011.png'] Loaded
# ['S034', '004', '00000012.png'] Loaded
# ['S034', '004', '00000013.png'] Loaded
# ['S034', '004', '00000014.png'] Loaded
# ['S034', '004', '00000015.png'] Loaded
# ['S034', '004', '00000016.png'] Loaded
# ['S034', '004', '00000017.png'] Loaded
# ['S034', '004', '00000018.png'] Loaded
# ['S034', '004', '00000019.png'] Loaded
# ['S034', '004', '00000020.png'] Loaded
# ['S034', '004', '00000021.png'] Loaded
# ['S034', '004', '00000022.png'] Loaded
# ['S034', '004', '00000023.png'] Loaded
# ['S034', '004', '00000024.png'] Loaded
# ['S034', '004', '00000025.png'] Loaded
# ['S034', '004', '00000026.png'] Loaded
# ['S034', '004', '00000027.png'] Loaded
# ['S034', '004', '00000028.png'] Loaded
# ['S034', '004', '00000029.png'] Loaded
# ['S034', '004', '00000030.png'] Loaded
# ['S034', '004', '00000031.png'] Loaded
# ['S034', '004', '00000032.png'] Loaded
# ['S034', '004', '00000033.png'] Loaded
# ['S034', '004', '00000034.png'] Loaded
# ['S034', '004', '00000035.png'] Loaded
# ['S034', '004', '00000036.png'] Loaded
# ['S034', '004', '00000037.png'] Loaded
# ['S034', '005', '00000001.png'] Loaded
# ['S034', '005', '00000002.png'] Loaded
# ['S034', '005', '00000003.png'] Loaded
# ['S034', '005', '00000004.png'] Loaded
# ['S034', '005', '00000005.png'] Loaded
# ['S034', '005', '00000006.png'] Loaded
# ['S034', '005', '00000007.png'] Loaded
# ['S034', '005', '00000008.png'] Loaded
# ['S034', '005', '00000009.png'] Loaded
# ['S034', '005', '00000010.png'] Loaded
# ['S035', '001', '00000001.png'] Loaded
# ['S035', '001', '00000002.png'] Loaded
# ['S035', '001', '00000003.png'] Loaded
# ['S035', '001', '00000004.png'] Loaded
# ['S035', '001', '00000005.png'] Loaded
# ['S035', '001', '00000006.png'] Loaded
# ['S035', '001', '00000007.png'] Loaded
# ['S035', '001', '00000008.png'] Loaded
# ['S035', '001', '00000009.png'] Loaded
# ['S035', '001', '00000010.png'] Loaded
# ['S035', '001', '00000011.png'] Loaded
# ['S035', '001', '00000012.png'] Loaded
# ['S035', '001', '00000013.png'] Loaded
# ['S035', '001', '00000014.png'] Loaded
# ['S035', '001', '00000015.png'] Loaded
# ['S035', '002', '00000001.png'] Loaded
# ['S035', '002', '00000002.png'] Loaded
# ['S035', '002', '00000003.png'] Loaded
# ['S035', '002', '00000004.png'] Loaded
# ['S035', '002', '00000005.png'] Loaded
# ['S035', '002', '00000006.png'] Loaded
# ['S035', '002', '00000007.png'] Loaded
# ['S035', '002', '00000008.png'] Loaded
# ['S035', '002', '00000009.png'] Loaded
# ['S035', '002', '00000010.png'] Loaded
# ['S035', '003', '00000001.png'] Loaded
# ['S035', '003', '00000002.png'] Loaded
# ['S035', '003', '00000003.png'] Loaded
# ['S035', '003', '00000004.png'] Loaded
# ['S035', '003', '00000005.png'] Loaded
# ['S035', '003', '00000006.png'] Loaded
# ['S035', '003', '00000007.png'] Loaded
# ['S035', '003', '00000008.png'] Loaded
# ['S035', '003', '00000009.png'] Loaded
# ['S035', '003', '00000010.png'] Loaded
# ['S035', '003', '00000011.png'] Loaded
# ['S035', '003', '00000012.png'] Loaded
# ['S035', '003', '00000013.png'] Loaded
# ['S035', '003', '00000014.png'] Loaded
# ['S035', '003', '00000015.png'] Loaded
# ['S035', '004', '00000001.png'] Loaded
# ['S035', '004', '00000002.png'] Loaded
# ['S035', '004', '00000003.png'] Loaded
# ['S035', '004', '00000004.png'] Loaded
# ['S035', '004', '00000005.png'] Loaded
# ['S035', '004', '00000006.png'] Loaded
# ['S035', '004', '00000007.png'] Loaded
# ['S035', '004', '00000008.png'] Loaded
# ['S035', '004', '00000009.png'] Loaded
# ['S035', '004', '00000010.png'] Loaded
# ['S035', '004', '00000011.png'] Loaded
# ['S035', '004', '00000012.png'] Loaded
# ['S035', '004', '00000013.png'] Loaded
# ['S035', '004', '00000014.png'] Loaded
# ['S035', '004', '00000015.png'] Loaded
# ['S035', '004', '00000016.png'] Loaded
# ['S035', '005', '00000001.png'] Loaded
# ['S035', '005', '00000002.png'] Loaded
# ['S035', '005', '00000003.png'] Loaded
# ['S035', '005', '00000004.png'] Loaded
# ['S035', '005', '00000005.png'] Loaded
# ['S035', '005', '00000006.png'] Loaded
# ['S035', '005', '00000007.png'] Loaded
# ['S035', '005', '00000008.png'] Loaded
# ['S035', '005', '00000009.png'] Loaded
# ['S035', '005', '00000010.png'] Loaded
# ['S035', '005', '00000011.png'] Loaded
# ['S035', '005', '00000012.png'] Loaded
# ['S035', '005', '00000013.png'] Loaded
# ['S035', '005', '00000014.png'] Loaded
# ['S035', '005', '00000015.png'] Loaded
# ['S035', '005', '00000016.png'] Loaded
# ['S035', '005', '00000017.png'] Loaded
# ['S035', '005', '00000018.png'] Loaded
# ['S035', '005', '00000019.png'] Loaded
# ['S035', '006', '00000001.png'] Loaded
# ['S035', '006', '00000002.png'] Loaded
# ['S035', '006', '00000003.png'] Loaded
# ['S035', '006', '00000004.png'] Loaded
# ['S035', '006', '00000005.png'] Loaded
# ['S035', '006', '00000006.png'] Loaded
# ['S035', '006', '00000007.png'] Loaded
# ['S035', '006', '00000008.png'] Loaded
# ['S035', '006', '00000009.png'] Loaded
# ['S035', '006', '00000010.png'] Loaded
# ['S035', '006', '00000011.png'] Loaded
# ['S035', '006', '00000012.png'] Loaded
# ['S035', '006', '00000013.png'] Loaded
# ['S035', '006', '00000014.png'] Loaded
# ['S035', '006', '00000015.png'] Loaded
# ['S035', '006', '00000016.png'] Loaded
# ['S035', '006', '00000017.png'] Loaded
# ['S035', '006', '00000018.png'] Loaded
# ['S037', '001', '00000001.png'] Loaded
# ['S037', '001', '00000002.png'] Loaded
# ['S037', '001', '00000003.png'] Loaded
# ['S037', '001', '00000004.png'] Loaded
# ['S037', '001', '00000005.png'] Loaded
# ['S037', '001', '00000006.png'] Loaded
# ['S037', '001', '00000007.png'] Loaded
# ['S037', '001', '00000008.png'] Loaded
# ['S037', '001', '00000009.png'] Loaded
# ['S037', '001', '00000010.png'] Loaded
# ['S037', '001', '00000011.png'] Loaded
# ['S037', '001', '00000012.png'] Loaded
# ['S037', '001', '00000013.png'] Loaded
# ['S037', '001', '00000014.png'] Loaded
# ['S037', '001', '00000015.png'] Loaded
# ['S037', '001', '00000016.png'] Loaded
# ['S037', '001', '00000017.png'] Loaded
# ['S037', '001', '00000018.png'] Loaded
# ['S037', '001', '00000019.png'] Loaded
# ['S037', '001', '00000020.png'] Loaded
# ['S037', '002', '00000001.png'] Loaded
# ['S037', '002', '00000002.png'] Loaded
# ['S037', '002', '00000003.png'] Loaded
# ['S037', '002', '00000004.png'] Loaded
# ['S037', '002', '00000005.png'] Loaded
# ['S037', '002', '00000006.png'] Loaded
# ['S037', '002', '00000007.png'] Loaded
# ['S037', '002', '00000008.png'] Loaded
# ['S037', '002', '00000009.png'] Loaded
# ['S037', '002', '00000010.png'] Loaded
# ['S037', '002', '00000011.png'] Loaded
# ['S037', '002', '00000012.png'] Loaded
# ['S037', '002', '00000013.png'] Loaded
# ['S037', '002', '00000014.png'] Loaded
# ['S037', '002', '00000015.png'] Loaded
# ['S037', '002', '00000016.png'] Loaded
# ['S037', '002', '00000017.png'] Loaded
# ['S037', '003', '00000001.png'] Loaded
# ['S037', '003', '00000002.png'] Loaded
# ['S037', '003', '00000003.png'] Loaded
# ['S037', '003', '00000004.png'] Loaded
# ['S037', '003', '00000005.png'] Loaded
# ['S037', '003', '00000006.png'] Loaded
# ['S037', '003', '00000007.png'] Loaded
# ['S037', '003', '00000008.png'] Loaded
# ['S037', '003', '00000009.png'] Loaded
# ['S037', '003', '00000010.png'] Loaded
# ['S037', '003', '00000011.png'] Loaded
# ['S037', '003', '00000012.png'] Loaded
# ['S037', '003', '00000013.png'] Loaded
# ['S037', '003', '00000014.png'] Loaded
# ['S037', '003', '00000015.png'] Loaded
# ['S037', '003', '00000016.png'] Loaded
# ['S037', '003', '00000017.png'] Loaded
# ['S037', '003', '00000018.png'] Loaded
# ['S037', '003', '00000019.png'] Loaded
# ['S037', '003', '00000020.png'] Loaded
# ['S037', '003', '00000021.png'] Loaded
# ['S037', '003', '00000022.png'] Loaded
# ['S037', '004', '00000001.png'] Loaded
# ['S037', '004', '00000002.png'] Loaded
# ['S037', '004', '00000003.png'] Loaded
# ['S037', '004', '00000004.png'] Loaded
# ['S037', '004', '00000005.png'] Loaded
# ['S037', '004', '00000006.png'] Loaded
# ['S037', '004', '00000007.png'] Loaded
# ['S037', '004', '00000008.png'] Loaded
# ['S037', '004', '00000009.png'] Loaded
# ['S037', '004', '00000010.png'] Loaded
# ['S037', '004', '00000011.png'] Loaded
# ['S037', '004', '00000012.png'] Loaded
# ['S037', '004', '00000013.png'] Loaded
# ['S037', '004', '00000014.png'] Loaded
# ['S037', '004', '00000015.png'] Loaded
# ['S037', '004', '00000016.png'] Loaded
# ['S037', '004', '00000017.png'] Loaded
# ['S037', '004', '00000018.png'] Loaded
# ['S037', '004', '00000019.png'] Loaded
# ['S037', '004', '00000020.png'] Loaded
# ['S037', '004', '00000021.png'] Loaded
# ['S037', '004', '00000022.png'] Loaded
# ['S037', '004', '00000023.png'] Loaded
# ['S037', '004', '00000024.png'] Loaded
# ['S037', '004', '00000025.png'] Loaded
# ['S037', '004', '00000026.png'] Loaded
# ['S037', '004', '00000027.png'] Loaded
# ['S037', '004', '00000028.png'] Loaded
# ['S037', '004', '00000029.png'] Loaded
# ['S037', '004', '00000030.png'] Loaded
# ['S037', '004', '00000031.png'] Loaded
# ['S037', '004', '00000032.png'] Loaded
# ['S037', '004', '00000033.png'] Loaded
# ['S037', '004', '00000034.png'] Loaded
# ['S037', '004', '00000035.png'] Loaded
# ['S037', '004', '00000036.png'] Loaded
# ['S037', '004', '00000037.png'] Loaded
# ['S037', '004', '00000038.png'] Loaded
# ['S037', '004', '00000039.png'] Loaded
# ['S037', '004', '00000040.png'] Loaded
# ['S037', '004', '00000041.png'] Loaded
# ['S037', '004', '00000042.png'] Loaded
# ['S037', '004', '00000043.png'] Loaded
# ['S037', '004', '00000044.png'] Loaded
# ['S037', '004', '00000045.png'] Loaded
# ['S037', '004', '00000046.png'] Loaded
# ['S037', '004', '00000047.png'] Loaded
# ['S037', '004', '00000048.png'] Loaded
# ['S037', '004', '00000049.png'] Loaded
# ['S037', '004', '00000050.png'] Loaded
# ['S037', '004', '00000051.png'] Loaded
# ['S037', '004', '00000052.png'] Loaded
# ['S037', '004', '00000053.png'] Loaded
# ['S037', '004', '00000054.png'] Loaded
# ['S037', '004', '00000055.png'] Loaded
# ['S037', '004', '00000056.png'] Loaded
# ['S037', '004', '00000057.png'] Loaded
# ['S037', '004', '00000058.png'] Loaded
# ['S037', '004', '00000059.png'] Loaded
# ['S037', '004', '00000060.png'] Loaded
# ['S037', '004', '00000061.png'] Loaded
# ['S037', '004', '00000062.png'] Loaded
# ['S037', '004', '00000063.png'] Loaded
# ['S037', '004', '00000064.png'] Loaded
# ['S037', '004', '00000065.png'] Loaded
# ['S037', '004', '00000066.png'] Loaded
# ['S037', '005', '00000001.png'] Loaded
# ['S037', '005', '00000002.png'] Loaded
# ['S037', '005', '00000003.png'] Loaded
# ['S037', '005', '00000004.png'] Loaded
# ['S037', '005', '00000005.png'] Loaded
# ['S037', '005', '00000006.png'] Loaded
# ['S037', '005', '00000007.png'] Loaded
# ['S037', '005', '00000008.png'] Loaded
# ['S037', '005', '00000009.png'] Loaded
# ['S037', '005', '00000010.png'] Loaded
# ['S037', '005', '00000011.png'] Loaded
# ['S037', '005', '00000012.png'] Loaded
# ['S037', '005', '00000013.png'] Loaded
# ['S037', '005', '00000014.png'] Loaded
# ['S037', '005', '00000015.png'] Loaded
# ['S037', '005', '00000016.png'] Loaded
# ['S037', '005', '00000017.png'] Loaded
# ['S037', '005', '00000018.png'] Loaded
# ['S037', '005', '00000019.png'] Loaded
# ['S037', '005', '00000020.png'] Loaded
# ['S037', '005', '00000021.png'] Loaded
# ['S037', '005', '00000022.png'] Loaded
# ['S037', '006', '00000001.png'] Loaded
# ['S037', '006', '00000002.png'] Loaded
# ['S037', '006', '00000003.png'] Loaded
# ['S037', '006', '00000004.png'] Loaded
# ['S037', '006', '00000005.png'] Loaded
# ['S037', '006', '00000006.png'] Loaded
# ['S037', '006', '00000007.png'] Loaded
# ['S037', '006', '00000008.png'] Loaded
# ['S037', '006', '00000009.png'] Loaded
# ['S037', '006', '00000010.png'] Loaded
# ['S037', '006', '00000011.png'] Loaded
# ['S037', '006', '00000012.png'] Loaded
# ['S037', '006', '00000013.png'] Loaded
# ['S037', '006', '00000014.png'] Loaded
# ['S037', '006', '00000015.png'] Loaded
# ['S037', '006', '00000016.png'] Loaded
# ['S037', '006', '00000017.png'] Loaded
# ['S037', '006', '00000018.png'] Loaded
# ['S037', '006', '00000019.png'] Loaded
# ['S037', '006', '00000020.png'] Loaded
# ['S037', '006', '00000021.png'] Loaded
# ['S042', '001', '00000001.png'] Loaded
# ['S042', '001', '00000002.png'] Loaded
# ['S042', '001', '00000003.png'] Loaded
# ['S042', '001', '00000004.png'] Loaded
# ['S042', '001', '00000005.png'] Loaded
# ['S042', '001', '00000006.png'] Loaded
# ['S042', '001', '00000007.png'] Loaded
# ['S042', '001', '00000008.png'] Loaded
# ['S042', '001', '00000009.png'] Loaded
# ['S042', '001', '00000010.png'] Loaded
# ['S042', '001', '00000011.png'] Loaded
# ['S042', '001', '00000012.png'] Loaded
# ['S042', '001', '00000013.png'] Loaded
# ['S042', '001', '00000014.png'] Loaded
# ['S042', '001', '00000015.png'] Loaded
# ['S042', '001', '00000016.png'] Loaded
# ['S042', '001', '00000017.png'] Loaded
# ['S042', '001', '00000018.png'] Loaded
# ['S042', '001', '00000019.png'] Loaded
# ['S042', '002', '00000001.png'] Loaded
# ['S042', '002', '00000002.png'] Loaded
# ['S042', '002', '00000003.png'] Loaded
# ['S042', '002', '00000004.png'] Loaded
# ['S042', '002', '00000005.png'] Loaded
# ['S042', '002', '00000006.png'] Loaded
# ['S042', '002', '00000007.png'] Loaded
# ['S042', '002', '00000008.png'] Loaded
# ['S042', '002', '00000009.png'] Loaded
# ['S042', '002', '00000010.png'] Loaded
# ['S042', '002', '00000011.png'] Loaded
# ['S042', '002', '00000012.png'] Loaded
# ['S042', '002', '00000013.png'] Loaded
# ['S042', '002', '00000014.png'] Loaded
# ['S042', '002', '00000015.png'] Loaded
# ['S042', '002', '00000016.png'] Loaded
# ['S042', '003', '00000001.png'] Loaded
# ['S042', '003', '00000002.png'] Loaded
# ['S042', '003', '00000003.png'] Loaded
# ['S042', '003', '00000004.png'] Loaded
# ['S042', '003', '00000005.png'] Loaded
# ['S042', '003', '00000006.png'] Loaded
# ['S042', '003', '00000007.png'] Loaded
# ['S042', '003', '00000008.png'] Loaded
# ['S042', '003', '00000009.png'] Loaded
# ['S042', '003', '00000010.png'] Loaded
# ['S042', '003', '00000011.png'] Loaded
# ['S042', '003', '00000012.png'] Loaded
# ['S042', '003', '00000013.png'] Loaded
# ['S042', '003', '00000014.png'] Loaded
# ['S042', '004', '00000001.png'] Loaded
# ['S042', '004', '00000002.png'] Loaded
# ['S042', '004', '00000003.png'] Loaded
# ['S042', '004', '00000004.png'] Loaded
# ['S042', '004', '00000005.png'] Loaded
# ['S042', '004', '00000006.png'] Loaded
# ['S042', '004', '00000007.png'] Loaded
# ['S042', '004', '00000008.png'] Loaded
# ['S042', '004', '00000009.png'] Loaded
# ['S042', '004', '00000010.png'] Loaded
# ['S042', '004', '00000011.png'] Loaded
# ['S042', '004', '00000012.png'] Loaded
# ['S042', '004', '00000013.png'] Loaded
# ['S042', '004', '00000014.png'] Loaded
# ['S042', '004', '00000015.png'] Loaded
# ['S042', '004', '00000016.png'] Loaded
# ['S042', '004', '00000017.png'] Loaded
# ['S042', '004', '00000018.png'] Loaded
# ['S042', '004', '00000019.png'] Loaded
# ['S042', '004', '00000020.png'] Loaded
# ['S042', '005', '00000001.png'] Loaded
# ['S042', '005', '00000002.png'] Loaded
# ['S042', '005', '00000003.png'] Loaded
# ['S042', '005', '00000004.png'] Loaded
# ['S042', '005', '00000005.png'] Loaded
# ['S042', '005', '00000006.png'] Loaded
# ['S042', '005', '00000007.png'] Loaded
# ['S042', '005', '00000008.png'] Loaded
# ['S042', '005', '00000009.png'] Loaded
# ['S042', '005', '00000010.png'] Loaded
# ['S042', '005', '00000011.png'] Loaded
# ['S042', '005', '00000012.png'] Loaded
# ['S042', '005', '00000013.png'] Loaded
# ['S042', '005', '00000014.png'] Loaded
# ['S042', '005', '00000015.png'] Loaded
# ['S042', '005', '00000016.png'] Loaded
# ['S042', '005', '00000017.png'] Loaded
# ['S042', '005', '00000018.png'] Loaded
# ['S042', '005', '00000019.png'] Loaded
# ['S042', '006', '00000001.png'] Loaded
# ['S042', '006', '00000002.png'] Loaded
# ['S042', '006', '00000003.png'] Loaded
# ['S042', '006', '00000004.png'] Loaded
# ['S042', '006', '00000005.png'] Loaded
# ['S042', '006', '00000006.png'] Loaded
# ['S042', '006', '00000007.png'] Loaded
# ['S042', '006', '00000008.png'] Loaded
# ['S042', '006', '00000009.png'] Loaded
# ['S042', '006', '00000010.png'] Loaded
# ['S042', '006', '00000011.png'] Loaded
# ['S042', '006', '00000012.png'] Loaded
# ['S042', '006', '00000013.png'] Loaded
# ['S042', '006', '00000014.png'] Loaded
# ['S042', '006', '00000015.png'] Loaded
# ['S042', '006', '00000016.png'] Loaded
# ['S042', '006', '00000017.png'] Loaded
# ['S044', '001', '00000001.png'] Loaded
# ['S044', '001', '00000002.png'] Loaded
# ['S044', '001', '00000003.png'] Loaded
# ['S044', '001', '00000004.png'] Loaded
# ['S044', '001', '00000005.png'] Loaded
# ['S044', '001', '00000006.png'] Loaded
# ['S044', '001', '00000007.png'] Loaded
# ['S044', '001', '00000008.png'] Loaded
# ['S044', '001', '00000009.png'] Loaded
# ['S044', '001', '00000010.png'] Loaded
# ['S044', '001', '00000011.png'] Loaded
# ['S044', '001', '00000012.png'] Loaded
# ['S044', '001', '00000013.png'] Loaded
# ['S044', '001', '00000014.png'] Loaded
# ['S044', '001', '00000015.png'] Loaded
# ['S044', '001', '00000016.png'] Loaded
# ['S044', '001', '00000017.png'] Loaded
# ['S044', '001', '00000018.png'] Loaded
# ...
# ['S503', '001', '00000003.png'] Loaded
# ['S503', '001', '00000004.png'] Loaded
# ['S503', '001', '00000005.png'] Loaded
# ['S503', '001', '00000006.png'] Loaded
# ['S503', '001', '00000007.png'] Loaded
# ['S503', '001', '00000008.png'] Loaded
# ['S503', '001', '00000009.png'] Loaded
# ['S503', '001', '00000010.png'] Loaded
# ['S503', '001', '00000011.png'] Loaded
# ['S503', '001', '00000012.png'] Loaded
# ['S503', '001', '00000013.png'] Loaded
# ['S503', '001', '00000014.png'] Loaded
# ['S503', '001', '00000015.png'] Loaded
# ['S503', '001', '00000016.png'] Loaded
# ['S503', '001', '00000017.png'] Loaded
# ['S503', '001', '00000018.png'] Loaded
# ['S503', '001', '00000019.png'] Loaded
# ['S503', '001', '00000020.png'] Loaded
# ['S503', '001', '00000021.png'] Loaded
# ['S503', '001', '00000022.png'] Loaded
# ['S503', '001', '00000023.png'] Loaded
# ['S503', '001', '00000024.png'] Loaded
# ['S503', '001', '00000025.png'] Loaded
# ['S503', '001', '00000026.png'] Loaded
# ['S503', '001', '00000027.png'] Loaded
# ['S503', '001', '00000028.png'] Loaded
# ['S503', '001', '00000029.png'] Loaded
# ['S503', '001', '00000030.png'] Loaded
# ['S503', '001', '00000031.png'] Loaded
# ['S503', '001', '00000032.png'] Loaded
# ['S503', '001', '00000033.png'] Loaded
# ['S503', '001', '00000034.png'] Loaded
# ['S503', '001', '00000035.png'] Loaded
# ['S503', '001', '00000036.png'] Loaded
# ['S503', '001', '00000037.png'] Loaded
# ['S503', '001', '00000038.png'] Loaded
# ['S503', '001', '00000039.png'] Loaded
# ['S503', '001', '00000040.png'] Loaded
# ['S503', '001', '00000041.png'] Loaded
# ['S503', '001', '00000042.png'] Loaded
# ['S503', '001', '00000043.png'] Loaded
# ['S503', '001', '00000044.png'] Loaded
# ['S503', '001', '00000045.png'] Loaded
# ['S503', '001', '00000046.png'] Loaded
# ['S503', '001', '00000047.png'] Loaded
# ['S503', '001', '00000048.png'] Loaded
# ['S503', '001', '00000049.png'] Loaded
# ['S503', '001', '00000050.png'] Loaded
# ['S503', '001', '00000051.png'] Loaded
# ['S503', '001', '00000052.png'] Loaded
# ['S503', '001', '00000053.png'] Loaded
# ['S503', '001', '00000054.png'] Loaded
# ['S503', '001', '00000055.png'] Loaded
# ['S503', '001', '00000056.png'] Loaded
# ['S503', '001', '00000057.png'] Loaded
# ['S503', '001', '00000058.png'] Loaded
# ['S503', '001', '00000059.png'] Loaded
# ['S503', '001', '00000060.png'] Loaded
# ['S503', '001', '00000061.png'] Loaded
# ['S503', '001', '00000062.png'] Loaded
# ['S503', '001', '00000063.png'] Loaded
# ['S503', '001', '00000064.png'] Loaded
# ['S503', '001', '00000065.png'] Loaded
# ['S503', '001', '00000066.png'] Loaded
# ['S503', '001', '00000067.png'] Loaded
# ['S503', '001', '00000068.png'] Loaded
# ['S503', '001', '00000069.png'] Loaded
# ['S503', '001', '00000070.png'] Loaded
# ['S503', '001', '00000071.png'] Loaded
# ['S503', '002', '00000001.png'] Loaded
# ['S503', '002', '00000002.png'] Loaded
# ['S503', '002', '00000003.png'] Loaded
# ['S503', '002', '00000004.png'] Loaded
# ['S503', '002', '00000005.png'] Loaded
# ['S503', '002', '00000006.png'] Loaded
# ['S503', '002', '00000007.png'] Loaded
# ['S503', '002', '00000008.png'] Loaded
# ['S503', '006', '00000001.png'] Loaded
# ['S503', '006', '00000002.png'] Loaded
# ['S503', '006', '00000003.png'] Loaded
# ['S503', '006', '00000004.png'] Loaded
# ['S503', '006', '00000005.png'] Loaded
# ['S503', '006', '00000006.png'] Loaded
# ['S503', '006', '00000007.png'] Loaded
# ['S503', '006', '00000008.png'] Loaded
# ['S503', '006', '00000009.png'] Loaded
# ['S503', '006', '00000010.png'] Loaded
# ['S503', '006', '00000011.png'] Loaded
# ['S503', '006', '00000012.png'] Loaded
# ['S503', '006', '00000013.png'] Loaded
# ['S503', '006', '00000014.png'] Loaded
# ['S503', '006', '00000015.png'] Loaded
# ['S503', '006', '00000016.png'] Loaded
# ['S503', '006', '00000017.png'] Loaded
# ['S503', '006', '00000018.png'] Loaded
# ['S503', '006', '00000019.png'] Loaded
# ['S503', '006', '00000020.png'] Loaded
# ['S504', '001', '00000001.png'] Loaded
# ['S504', '001', '00000002.png'] Loaded
# ['S504', '001', '00000003.png'] Loaded
# ['S504', '001', '00000004.png'] Loaded
# ['S504', '001', '00000005.png'] Loaded
# ['S504', '001', '00000006.png'] Loaded
# ['S504', '001', '00000007.png'] Loaded
# ['S504', '001', '00000008.png'] Loaded
# ['S504', '001', '00000009.png'] Loaded
# ['S504', '001', '00000010.png'] Loaded
# ['S504', '001', '00000011.png'] Loaded
# ['S504', '001', '00000012.png'] Loaded
# ['S504', '001', '00000013.png'] Loaded
# ['S504', '001', '00000014.png'] Loaded
# ['S504', '001', '00000015.png'] Loaded
# ['S504', '001', '00000016.png'] Loaded
# ['S504', '001', '00000017.png'] Loaded
# ['S504', '001', '00000018.png'] Loaded
# ['S504', '001', '00000019.png'] Loaded
# ['S504', '001', '00000020.png'] Loaded
# ['S504', '001', '00000021.png'] Loaded
# ['S504', '001', '00000022.png'] Loaded
# ['S504', '002', '00000001.png'] Loaded
# ['S504', '002', '00000002.png'] Loaded
# ['S504', '002', '00000003.png'] Loaded
# ['S504', '002', '00000004.png'] Loaded
# ['S504', '002', '00000005.png'] Loaded
# ['S504', '002', '00000006.png'] Loaded
# ['S504', '002', '00000007.png'] Loaded
# ['S504', '002', '00000008.png'] Loaded
# ['S504', '002', '00000009.png'] Loaded
# ['S504', '004', '00000001.png'] Loaded
# ['S504', '004', '00000002.png'] Loaded
# ['S504', '004', '00000003.png'] Loaded
# ['S504', '004', '00000004.png'] Loaded
# ['S504', '004', '00000005.png'] Loaded
# ['S504', '004', '00000006.png'] Loaded
# ['S504', '004', '00000007.png'] Loaded
# ['S504', '004', '00000008.png'] Loaded
# ['S504', '004', '00000009.png'] Loaded
# ['S504', '004', '00000010.png'] Loaded
# ['S504', '004', '00000011.png'] Loaded
# ['S504', '004', '00000012.png'] Loaded
# ['S504', '004', '00000013.png'] Loaded
# ['S504', '004', '00000014.png'] Loaded
# ['S504', '004', '00000015.png'] Loaded
# ['S504', '006', '00000001.png'] Loaded
# ['S504', '006', '00000002.png'] Loaded
# ['S504', '006', '00000003.png'] Loaded
# ['S504', '006', '00000004.png'] Loaded
# ['S504', '006', '00000005.png'] Loaded
# ['S504', '006', '00000006.png'] Loaded
# ['S504', '006', '00000007.png'] Loaded
# ['S504', '006', '00000008.png'] Loaded
# ['S504', '006', '00000009.png'] Loaded
# ['S504', '006', '00000010.png'] Loaded
# ['S504', '006', '00000011.png'] Loaded
# ['S504', '006', '00000012.png'] Loaded
# ['S504', '006', '00000013.png'] Loaded
# ['S504', '006', '00000014.png'] Loaded
# ['S504', '006', '00000015.png'] Loaded
# ['S504', '006', '00000016.png'] Loaded
# ['S504', '006', '00000017.png'] Loaded
# ['S504', '006', '00000018.png'] Loaded
# ['S505', '002', '00000001.png'] Loaded
# ['S505', '002', '00000002.png'] Loaded
# ['S505', '002', '00000003.png'] Loaded
# ['S505', '002', '00000004.png'] Loaded
# ['S505', '002', '00000005.png'] Loaded
# ['S505', '002', '00000006.png'] Loaded
# ['S505', '002', '00000007.png'] Loaded
# ['S505', '002', '00000008.png'] Loaded
# ['S505', '002', '00000009.png'] Loaded
# ['S505', '002', '00000010.png'] Loaded
# ['S505', '002', '00000011.png'] Loaded
# ['S505', '002', '00000012.png'] Loaded
# ['S505', '002', '00000013.png'] Loaded
# ['S505', '002', '00000014.png'] Loaded
# ['S505', '002', '00000015.png'] Loaded
# ['S505', '002', '00000016.png'] Loaded
# ['S505', '002', '00000017.png'] Loaded
# ['S505', '002', '00000018.png'] Loaded
# ['S505', '002', '00000019.png'] Loaded
# ['S505', '002', '00000020.png'] Loaded
# ['S505', '002', '00000021.png'] Loaded
# ['S505', '006', '00000001.png'] Loaded
# ['S505', '006', '00000002.png'] Loaded
# ['S505', '006', '00000003.png'] Loaded
# ['S505', '006', '00000004.png'] Loaded
# ['S505', '006', '00000005.png'] Loaded
# ['S505', '006', '00000006.png'] Loaded
# ['S505', '006', '00000007.png'] Loaded
# ['S505', '006', '00000008.png'] Loaded
# ['S505', '006', '00000009.png'] Loaded
# ['S505', '006', '00000010.png'] Loaded
# ['S505', '006', '00000011.png'] Loaded
# ['S505', '006', '00000012.png'] Loaded
# ['S505', '006', '00000013.png'] Loaded
# ['S505', '006', '00000014.png'] Loaded
# ['S505', '006', '00000015.png'] Loaded
# ['S505', '006', '00000016.png'] Loaded
# ['S505', '006', '00000017.png'] Loaded
# ['S505', '006', '00000018.png'] Loaded
# ['S505', '006', '00000019.png'] Loaded
# ['S506', '001', '00000001.png'] Loaded
# ['S506', '001', '00000002.png'] Loaded
# ['S506', '001', '00000003.png'] Loaded
# ['S506', '001', '00000004.png'] Loaded
# ['S506', '001', '00000005.png'] Loaded
# ['S506', '001', '00000006.png'] Loaded
# ['S506', '001', '00000007.png'] Loaded
# ['S506', '001', '00000008.png'] Loaded
# ['S506', '001', '00000009.png'] Loaded
# ['S506', '001', '00000010.png'] Loaded
# ['S506', '001', '00000011.png'] Loaded
# ['S506', '001', '00000012.png'] Loaded
# ['S506', '001', '00000013.png'] Loaded
# ['S506', '001', '00000014.png'] Loaded
# ['S506', '001', '00000015.png'] Loaded
# ['S506', '001', '00000016.png'] Loaded
# ['S506', '001', '00000017.png'] Loaded
# ['S506', '001', '00000018.png'] Loaded
# ['S506', '001', '00000019.png'] Loaded
# ['S506', '001', '00000020.png'] Loaded
# ['S506', '001', '00000021.png'] Loaded
# ['S506', '001', '00000022.png'] Loaded
# ['S506', '001', '00000023.png'] Loaded
# ['S506', '001', '00000024.png'] Loaded
# ['S506', '001', '00000025.png'] Loaded
# ['S506', '001', '00000026.png'] Loaded
# ['S506', '001', '00000027.png'] Loaded
# ['S506', '001', '00000028.png'] Loaded
# ['S506', '001', '00000029.png'] Loaded
# ['S506', '001', '00000030.png'] Loaded
# ['S506', '001', '00000031.png'] Loaded
# ['S506', '001', '00000032.png'] Loaded
# ['S506', '001', '00000033.png'] Loaded
# ['S506', '001', '00000034.png'] Loaded
# ['S506', '001', '00000035.png'] Loaded
# ['S506', '001', '00000036.png'] Loaded
# ['S506', '001', '00000037.png'] Loaded
# ['S506', '001', '00000038.png'] Loaded
# ['S506', '001', '00000039.png'] Loaded
# ['S506', '001', '00000040.png'] Loaded
# ['S506', '002', '00000001.png'] Loaded
# ['S506', '002', '00000002.png'] Loaded
# ['S506', '002', '00000003.png'] Loaded
# ['S506', '002', '00000004.png'] Loaded
# ['S506', '002', '00000005.png'] Loaded
# ['S506', '002', '00000006.png'] Loaded
# ['S506', '002', '00000007.png'] Loaded
# ['S506', '002', '00000008.png'] Loaded
# ['S506', '002', '00000009.png'] Loaded
# ['S506', '004', '00000001.png'] Loaded
# ['S506', '004', '00000002.png'] Loaded
# ['S506', '004', '00000003.png'] Loaded
# ['S506', '004', '00000004.png'] Loaded
# ['S506', '004', '00000005.png'] Loaded
# ['S506', '004', '00000006.png'] Loaded
# ['S506', '004', '00000007.png'] Loaded
# ['S506', '004', '00000008.png'] Loaded
# ['S506', '004', '00000009.png'] Loaded
# ['S506', '004', '00000010.png'] Loaded
# ['S506', '004', '00000011.png'] Loaded
# ['S506', '004', '00000012.png'] Loaded
# ['S506', '004', '00000013.png'] Loaded
# ['S506', '004', '00000014.png'] Loaded
# ['S506', '004', '00000015.png'] Loaded
# ['S506', '004', '00000016.png'] Loaded
# ['S506', '004', '00000017.png'] Loaded
# ['S506', '004', '00000018.png'] Loaded
# ['S506', '004', '00000019.png'] Loaded
# ['S506', '004', '00000020.png'] Loaded
# ['S506', '004', '00000021.png'] Loaded
# ['S506', '004', '00000022.png'] Loaded
# ['S506', '004', '00000023.png'] Loaded
# ['S506', '004', '00000024.png'] Loaded
# ['S506', '004', '00000025.png'] Loaded
# ['S506', '004', '00000026.png'] Loaded
# ['S506', '004', '00000027.png'] Loaded
# ['S506', '004', '00000028.png'] Loaded
# ['S506', '004', '00000029.png'] Loaded
# ['S506', '004', '00000030.png'] Loaded
# ['S506', '004', '00000031.png'] Loaded
# ['S506', '004', '00000032.png'] Loaded
# ['S506', '004', '00000033.png'] Loaded
# ['S506', '004', '00000034.png'] Loaded
# ['S506', '004', '00000035.png'] Loaded
# ['S506', '004', '00000036.png'] Loaded
# ['S506', '004', '00000037.png'] Loaded
# ['S506', '004', '00000038.png'] Loaded
# ['S506', '006', '00000001.png'] Loaded
# ['S506', '006', '00000002.png'] Loaded
# ['S506', '006', '00000003.png'] Loaded
# ['S506', '006', '00000004.png'] Loaded
# ['S506', '006', '00000005.png'] Loaded
# ['S506', '006', '00000006.png'] Loaded
# ['S506', '006', '00000007.png'] Loaded
# ['S506', '006', '00000008.png'] Loaded
# ['S506', '006', '00000009.png'] Loaded
# ['S506', '006', '00000010.png'] Loaded
# ['S506', '006', '00000011.png'] Loaded
# ['S506', '006', '00000012.png'] Loaded
# ['S506', '006', '00000013.png'] Loaded
# ['S506', '006', '00000014.png'] Loaded
# ['S506', '006', '00000015.png'] Loaded
# ['S506', '006', '00000016.png'] Loaded
# ['S506', '006', '00000017.png'] Loaded
# ['S506', '006', '00000018.png'] Loaded
# ['S506', '006', '00000019.png'] Loaded
# ['S506', '006', '00000020.png'] Loaded
# ['S506', '006', '00000021.png'] Loaded
# ['S506', '006', '00000022.png'] Loaded
# ['S506', '006', '00000023.png'] Loaded
# ['S506', '006', '00000024.png'] Loaded
# ['S506', '006', '00000025.png'] Loaded
# ['S506', '006', '00000026.png'] Loaded
# ['S506', '006', '00000027.png'] Loaded
# ['S506', '006', '00000028.png'] Loaded
# ['S506', '006', '00000029.png'] Loaded
# ['S506', '006', '00000030.png'] Loaded
# ['S506', '006', '00000031.png'] Loaded
# ['S506', '006', '00000032.png'] Loaded
# ['S506', '006', '00000033.png'] Loaded
# ['S506', '006', '00000034.png'] Loaded
# ['S506', '006', '00000035.png'] Loaded
# ['S506', '006', '00000036.png'] Loaded
# ['S506', '006', '00000037.png'] Loaded
# ['S506', '006', '00000038.png'] Loaded
# ['S506', '006', '00000039.png'] Loaded
# ['S506', '006', '00000040.png'] Loaded
# ['S506', '006', '00000041.png'] Loaded
# ['S506', '006', '00000042.png'] Loaded
# ['S895', '002', '00000001.png'] Loaded
# ['S895', '002', '00000002.png'] Loaded
# ['S895', '002', '00000003.png'] Loaded
# ['S895', '002', '00000004.png'] Loaded
# ['S895', '002', '00000005.png'] Loaded
# ['S895', '002', '00000006.png'] Loaded
# ['S895', '002', '00000007.png'] Loaded
# ['S999', '001', '00000001.png'] Loaded
# ['S999', '001', '00000002.png'] Loaded
# ['S999', '001', '00000003.png'] Loaded
# ['S999', '001', '00000004.png'] Loaded
# ['S999', '001', '00000005.png'] Loaded
# ['S999', '001', '00000006.png'] Loaded
# ['S999', '001', '00000007.png'] Loaded
# ['S999', '001', '00000008.png'] Loaded
# ['S999', '001', '00000009.png'] Loaded
# ['S999', '001', '00000010.png'] Loaded
# ['S999', '001', '00000011.png'] Loaded
# ['S999', '001', '00000012.png'] Loaded
# ['S999', '001', '00000013.png'] Loaded
# ['S999', '001', '00000014.png'] Loaded
# ['S999', '001', '00000015.png'] Loaded
# ['S999', '001', '00000016.png'] Loaded
# ['S999', '001', '00000017.png'] Loaded
# ['S999', '001', '00000018.png'] Loaded
# ['S999', '003', '00000001.png'] Loaded
# ['S999', '003', '00000002.png'] Loaded
# ['S999', '003', '00000003.png'] Loaded
# ['S999', '003', '00000004.png'] Loaded
# ['S999', '003', '00000005.png'] Loaded
# ['S999', '003', '00000006.png'] Loaded
# ['S999', '003', '00000007.png'] Loaded
# ['S999', '003', '00000008.png'] Loaded
# ['S999', '003', '00000009.png'] Loaded
# ['S999', '003', '00000010.png'] Loaded
# ['S999', '003', '00000011.png'] Loaded
# ['S999', '003', '00000012.png'] Loaded
# ['S999', '003', '00000013.png'] Loaded
# ['S999', '003', '00000014.png'] Loaded
# ['S999', '003', '00000015.png'] Loaded
# ['S999', '003', '00000016.png'] Loaded
# ['S999', '003', '00000017.png'] Loaded
# ['S999', '003', '00000018.png'] Loaded
# ['S999', '003', '00000019.png'] Loaded
# ['S999', '003', '00000020.png'] Loaded
# ['S999', '003', '00000021.png'] Loaded
# ['S999', '003', '00000022.png'] Loaded
# ['S999', '003', '00000023.png'] Loaded
# ['S999', '003', '00000024.png'] Loaded
# ['S999', '003', '00000025.png'] Loaded
# ['S999', '003', '00000026.png'] Loaded
# ['S999', '003', '00000027.png'] Loaded
# ['S999', '003', '00000028.png'] Loaded
# ['S999', '003', '00000029.png'] Loaded
# ['S999', '003', '00000030.png'] Loaded
# ['S999', '003', '00000031.png'] Loaded
# ['S999', '003', '00000032.png'] Loaded
# ['S999', '003', '00000033.png'] Loaded
# ['S999', '003', '00000034.png'] Loaded
# ['S999', '003', '00000035.png'] Loaded
# ['S999', '003', '00000036.png'] Loaded
# ['S999', '003', '00000037.png'] Loaded
# ['S999', '003', '00000038.png'] Loaded
# ['S999', '003', '00000039.png'] Loaded
# ['S999', '003', '00000040.png'] Loaded
# ['S999', '003', '00000041.png'] Loaded
# ['S999', '003', '00000042.png'] Loaded
# ['S999', '003', '00000043.png'] Loaded
# ['S999', '003', '00000044.png'] Loaded
# ['S999', '003', '00000045.png'] Loaded
# ['S999', '003', '00000046.png'] Loaded
# ['S999', '003', '00000047.png'] Loaded
# ['S999', '003', '00000048.png'] Loaded
# ['S999', '003', '00000049.png'] Loaded
# ['S999', '003', '00000050.png'] Loaded
# ['S999', '003', '00000051.png'] Loaded
# ['S999', '003', '00000052.png'] Loaded
# ['S999', '003', '00000053.png'] Loaded
# ['S999', '003', '00000054.png'] Loaded
# ['S999', '003', '00000055.png'] Loaded

# %%
X, Y1, Y2, Y3 = make_x_y(points, images, labels, labels2)

# %%
X_train, X_test, Y_train, Y_test, Y_train2, Y_test2, Y_train3, Y_test3 = prepare_train_test(X, Y1, Y2, Y3, W)
# 1: emotions
# 2: FACS
# 3: facial keypoints

# %%
input_shape = (W, W, 1)

# %% [markdown]
# # Plain CNN with a single output

# %%
visible = Input(shape=input_shape)
x = Conv2D(10, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(visible)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(20, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(30, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x)
x = GlobalMaxPooling2D()(x)
output = Dense(Y_train.shape[1], activation='softmax', kernel_initializer=my_init)(x)
model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 50, 50, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 10)        100
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 10)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 20)        1820
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 20)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 30)        5430
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 217
# =================================================================
# Total params: 7,567
# Trainable params: 7,567
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=['categorical_crossentropy'],
              optimizer=Adam(clipnorm = 1.), metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train,
          validation_data = (X_test, Y_test),
          batch_size = 64,
          epochs = 10,
          verbose = True,
          shuffle = False)
# Out:
# Train on 1982 samples, validate on 661 samples
# Epoch 1/10
# 1982/1982 [==============================] - 9s 5ms/step - loss: 10.1771 - acc: 0.2013 - val_loss: 9.7857 - val_acc: 0.2617
# Epoch 2/10
# 1982/1982 [==============================] - 8s 4ms/step - loss: 9.8479 - acc: 0.2225 - val_loss: 9.7958 - val_acc: 0.2073
# Epoch 3/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 9.6836 - acc: 0.2412 - val_loss: 9.5888 - val_acc: 0.2511
# Epoch 4/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 9.5785 - acc: 0.2593 - val_loss: 9.4756 - val_acc: 0.2738
# Epoch 5/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 8.0342 - acc: 0.2810 - val_loss: 5.3949 - val_acc: 0.3268
# Epoch 6/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 5.3215 - acc: 0.3431 - val_loss: 5.0127 - val_acc: 0.3570
# Epoch 7/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 4.2963 - acc: 0.3507 - val_loss: 3.6033 - val_acc: 0.4009
# Epoch 8/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 3.5525 - acc: 0.4132 - val_loss: 3.3676 - val_acc: 0.4100
# Epoch 9/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 3.4900 - acc: 0.4142 - val_loss: 3.2825 - val_acc: 0.4796
# Epoch 10/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 2.4425 - acc: 0.3845 - val_loss: 1.5959 - val_acc: 0.4115

# %%
pred = model.predict(X_test)
y_pred = [np.argmax(p) for p in pred]
y_true = [np.argmax(p) for p in Y_test]

print classification_report(y_true, y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.39      0.56      0.46       149
#           1       0.00      0.00      0.00        10
#           2       0.00      0.00      0.00        71
#           3       0.32      0.11      0.16        74
#           4       0.47      0.64      0.54       163
#           5       0.44      0.11      0.17        64
#           6       0.38      0.54      0.44       130
#
# avg / total       0.36      0.41      0.36       661
# /anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # CNN with auxiliary FACS output

# %%
visible = Input(shape=input_shape)
x = Conv2D(10, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(visible)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(20, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(30, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x)
x = GlobalMaxPooling2D()(x)
output = Dense(Y_train.shape[1], activation='softmax', name = 'emotion',
               kernel_initializer=my_init)(x)
output2 = Dense(Y_train2.shape[1], activation='sigmoid', name = 'facs',
                kernel_initializer=my_init)(x)
model = Model(inputs=visible, outputs=[output, output2])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 50, 50, 1)    0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 50, 50, 10)   100         input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 25, 25, 10)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 25, 25, 20)   1820        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 20)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 12, 12, 30)   5430        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 30)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# emotion (Dense)                 (None, 7)            217         global_max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# facs (Dense)                    (None, 35)           1085        global_max_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 8,652
# Trainable params: 8,652
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss=['categorical_crossentropy', 'binary_crossentropy'],
              optimizer=Adam(clipnorm = 1.), metrics = {'emotion': 'accuracy'}, loss_weights = [1, 1])

# %%
model.fit(X_train, [Y_train, Y_train2],
          validation_data = (X_test, [Y_test, Y_test2]),
          batch_size = 64,
          epochs = 10,
          verbose = True,
          shuffle = False)
# Out:
# Train on 1982 samples, validate on 661 samples
# Epoch 1/10
# 1982/1982 [==============================] - 7s 3ms/step - loss: 12.8519 - emotion_loss: 10.3772 - facs_loss: 2.4747 - emotion_acc: 0.2175 - val_loss: 12.0842 - val_emotion_loss: 10.2146 - val_facs_loss: 1.8696 - val_emotion_acc: 0.1422
# Epoch 2/10
# 1982/1982 [==============================] - 7s 4ms/step - loss: 9.0798 - emotion_loss: 7.9094 - facs_loss: 1.1704 - emotion_acc: 0.2503 - val_loss: 6.0267 - val_emotion_loss: 5.2797 - val_facs_loss: 0.7471 - val_emotion_acc: 0.3298
# Epoch 3/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 3.7467 - emotion_loss: 3.1165 - facs_loss: 0.6302 - emotion_acc: 0.2977 - val_loss: 2.1931 - val_emotion_loss: 1.6727 - val_facs_loss: 0.5205 - val_emotion_acc: 0.3737
# Epoch 4/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 2.0145 - emotion_loss: 1.5851 - facs_loss: 0.4294 - emotion_acc: 0.3794 - val_loss: 1.8435 - val_emotion_loss: 1.4654 - val_facs_loss: 0.3781 - val_emotion_acc: 0.4312
# Epoch 5/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.8062 - emotion_loss: 1.4421 - facs_loss: 0.3641 - emotion_acc: 0.4198 - val_loss: 1.7393 - val_emotion_loss: 1.3920 - val_facs_loss: 0.3473 - val_emotion_acc: 0.4221
# Epoch 6/10
# 1982/1982 [==============================] - 7s 4ms/step - loss: 1.6993 - emotion_loss: 1.3550 - facs_loss: 0.3443 - emotion_acc: 0.4506 - val_loss: 1.6711 - val_emotion_loss: 1.3367 - val_facs_loss: 0.3344 - val_emotion_acc: 0.4508
# Epoch 7/10
# 1982/1982 [==============================] - 7s 3ms/step - loss: 1.6220 - emotion_loss: 1.2901 - facs_loss: 0.3318 - emotion_acc: 0.4763 - val_loss: 1.5875 - val_emotion_loss: 1.2652 - val_facs_loss: 0.3223 - val_emotion_acc: 0.4887otion_loss: 1.2956 - facs_loss: 0.3322 - emotion_acc: 0.
# Epoch 8/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.5514 - emotion_loss: 1.2278 - facs_loss: 0.3236 - emotion_acc: 0.5050 - val_loss: 1.5395 - val_emotion_loss: 1.2240 - val_facs_loss: 0.3155 - val_emotion_acc: 0.5174
# Epoch 9/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.4987 - emotion_loss: 1.1815 - facs_loss: 0.3172 - emotion_acc: 0.5247 - val_loss: 1.5222 - val_emotion_loss: 1.2107 - val_facs_loss: 0.3116 - val_emotion_acc: 0.5129
# Epoch 10/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.4571 - emotion_loss: 1.1444 - facs_loss: 0.3127 - emotion_acc: 0.5429 - val_loss: 1.4952 - val_emotion_loss: 1.1872 - val_facs_loss: 0.3081 - val_emotion_acc: 0.5280

# %%
pred = model.predict(X_test)[0]
y_pred = [np.argmax(p) for p in pred]
y_true = [np.argmax(p) for p in Y_test]

print classification_report(y_true, y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.58      0.36      0.44       149
#           1       0.00      0.00      0.00        10
#           2       0.47      0.27      0.34        71
#           3       0.36      0.65      0.46        74
#           4       0.56      0.83      0.67       163
#           5       0.56      0.08      0.14        64
#           6       0.62      0.68      0.65       130
#
# avg / total       0.53      0.53      0.49       661

# %% [markdown]
# # CNN with auxiliary KEYPOINT output

# %%
visible = Input(shape=input_shape)
x = Conv2D(10, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(visible)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(20, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(30, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x)
x = GlobalMaxPooling2D()(x)
output = Dense(Y_train.shape[1], activation='softmax', name = 'emotion', kernel_initializer=my_init)(x)
output2 = Dense(Y_train3.shape[1], activation='linear', kernel_initializer=my_init)(x)
model = Model(inputs=visible, outputs=[output, output2])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 50, 50, 1)    0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 10)   100         input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 25, 25, 10)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 20)   1820        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 20)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 12, 30)   5430        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_3 (GlobalM (None, 30)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# emotion (Dense)                 (None, 7)            217         global_max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 136)          4216        global_max_pooling2d_3[0][0]
# ==================================================================================================
# Total params: 11,783
# Trainable params: 11,783
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss=['categorical_crossentropy', 'mse'],
              optimizer=Adam(clipnorm = 1.), metrics = {'emotion': 'accuracy'}, loss_weights = [1, 1])

# %%
model.fit(X_train, [Y_train, Y_train3],
          validation_data = (X_test, [Y_test, Y_test3]),
          batch_size = 64,
          epochs = 10,
          verbose = True,
          shuffle = False)
# Out:
# Train on 1982 samples, validate on 661 samples
# Epoch 1/10
# 1982/1982 [==============================] - 7s 3ms/step - loss: 42.6993 - emotion_loss: 4.9381 - dense_2_loss: 37.7612 - emotion_acc: 0.2220 - val_loss: 2.3144 - val_emotion_loss: 1.8729 - val_dense_2_loss: 0.4415 - val_emotion_acc: 0.2678
# Epoch 2/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 2.0071 - emotion_loss: 1.6848 - dense_2_loss: 0.3222 - emotion_acc: 0.3280 - val_loss: 1.8119 - val_emotion_loss: 1.5948 - val_dense_2_loss: 0.2171 - val_emotion_acc: 0.3374
# Epoch 3/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.6957 - emotion_loss: 1.5108 - dense_2_loss: 0.1849 - emotion_acc: 0.3910 - val_loss: 1.6497 - val_emotion_loss: 1.4773 - val_dense_2_loss: 0.1725 - val_emotion_acc: 0.3782
# Epoch 4/10
# 1982/1982 [==============================] - 7s 3ms/step - loss: 1.5818 - emotion_loss: 1.4177 - dense_2_loss: 0.1640 - emotion_acc: 0.4299 - val_loss: 1.5664 - val_emotion_loss: 1.3995 - val_dense_2_loss: 0.1669 - val_emotion_acc: 0.4266
# Epoch 5/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.5072 - emotion_loss: 1.3582 - dense_2_loss: 0.1490 - emotion_acc: 0.4632 - val_loss: 1.5034 - val_emotion_loss: 1.3559 - val_dense_2_loss: 0.1475 - val_emotion_acc: 0.4312
# Epoch 6/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.4410 - emotion_loss: 1.3061 - dense_2_loss: 0.1349 - emotion_acc: 0.4879 - val_loss: 1.4372 - val_emotion_loss: 1.3080 - val_dense_2_loss: 0.1292 - val_emotion_acc: 0.4660
# Epoch 7/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.3740 - emotion_loss: 1.2516 - dense_2_loss: 0.1224 - emotion_acc: 0.5121 - val_loss: 1.3955 - val_emotion_loss: 1.2820 - val_dense_2_loss: 0.1135 - val_emotion_acc: 0.4796
# Epoch 8/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.3209 - emotion_loss: 1.2077 - dense_2_loss: 0.1131 - emotion_acc: 0.5303 - val_loss: 1.3286 - val_emotion_loss: 1.2280 - val_dense_2_loss: 0.1006 - val_emotion_acc: 0.4932
# Epoch 9/10
# 1982/1982 [==============================] - 7s 3ms/step - loss: 1.2623 - emotion_loss: 1.1579 - dense_2_loss: 0.1044 - emotion_acc: 0.5600 - val_loss: 1.2939 - val_emotion_loss: 1.1961 - val_dense_2_loss: 0.0978 - val_emotion_acc: 0.5023
# Epoch 10/10
# 1982/1982 [==============================] - 6s 3ms/step - loss: 1.2084 - emotion_loss: 1.1080 - dense_2_loss: 0.1004 - emotion_acc: 0.5772 - val_loss: 1.2579 - val_emotion_loss: 1.1545 - val_dense_2_loss: 0.1034 - val_emotion_acc: 0.5189

# %%
pred = model.predict(X_test)[0]
y_pred = [np.argmax(p) for p in pred]
y_true = [np.argmax(p) for p in Y_test]

print classification_report(y_true, y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.69      0.34      0.45       149
#           1       0.00      0.00      0.00        10
#           2       0.71      0.07      0.13        71
#           3       0.38      0.65      0.48        74
#           4       0.52      0.88      0.65       163
#           5       0.50      0.05      0.09        64
#           6       0.53      0.72      0.61       130
#
# avg / total       0.56      0.52      0.46       661

# %% [markdown]
# # CNN with  FACS and KEYPOINT

# %%
visible = Input(shape=input_shape)
x1 = Conv2D(10, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(visible)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x2 = Conv2D(20, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x1)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x3 = Conv2D(30, kernel_size=3, activation='elu', padding='same', kernel_initializer=my_init)(x2)
x = GlobalMaxPooling2D()(x3)
output = Dense(Y_train.shape[1], activation='softmax', name = 'emotion', kernel_initializer=my_init)(x)
output2 = Dense(Y_train2.shape[1], activation='sigmoid', kernel_initializer=my_init)(GlobalMaxPooling2D()(x2))
output3 = Dense(Y_train3.shape[1], activation='linear', kernel_initializer=my_init)(GlobalMaxPooling2D()(x1))
model = Model(inputs=visible, outputs=[output, output2, output3])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 50, 50, 1)    0
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 10)   100         input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 25, 25, 10)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 20)   1820        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 12, 12, 20)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 12, 12, 30)   5430        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_4 (GlobalM (None, 30)           0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_5 (GlobalM (None, 20)           0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_6 (GlobalM (None, 10)           0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# emotion (Dense)                 (None, 7)            217         global_max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 35)           735         global_max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 136)          1496        global_max_pooling2d_6[0][0]
# ==================================================================================================
# Total params: 9,798
# Trainable params: 9,798
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss=['categorical_crossentropy', 'binary_crossentropy', 'mse'],
              optimizer=Adam(clipnorm = 1.), metrics = {'emotion': 'accuracy'}, loss_weights = [1, 1e-1, 1e-1])

# %%
model.fit(X_train, [Y_train, Y_train2, Y_train3],
          validation_data = (X_test, [Y_test, Y_test2, Y_test3]),
          batch_size = 64,
          epochs = 10,
          verbose = True,
          shuffle = False)
# Out:
# Train on 1982 samples, validate on 661 samples
# Epoch 1/10
# 1982/1982 [==============================] - 9s 5ms/step - loss: 35.3715 - emotion_loss: 10.2034 - dense_3_loss: 3.9324 - dense_4_loss: 247.7484 - emotion_acc: 0.2371 - val_loss: 16.8905 - val_emotion_loss: 10.1862 - val_dense_3_loss: 3.3374 - val_dense_4_loss: 63.7056 - val_emotion_acc: 0.2632
# Epoch 2/10
# 1982/1982 [==============================] - 9s 4ms/step - loss: 12.6271 - emotion_loss: 10.2749 - dense_3_loss: 2.2526 - dense_4_loss: 21.2701 - emotion_acc: 0.2558 - val_loss: 10.1059 - val_emotion_loss: 9.7049 - val_dense_3_loss: 1.3860 - val_dense_4_loss: 2.6245 - val_emotion_acc: 0.2632
# Epoch 3/10
# 1982/1982 [==============================] - 9s 5ms/step - loss: 7.7241 - emotion_loss: 7.3848 - dense_3_loss: 1.0280 - dense_4_loss: 2.3655 - emotion_acc: 0.2442 - val_loss: 3.5110 - val_emotion_loss: 3.2263 - val_dense_3_loss: 0.6811 - val_dense_4_loss: 2.1655 - val_emotion_acc: 0.3495
# Epoch 4/10
# 1982/1982 [==============================] - 9s 4ms/step - loss: 2.2452 - emotion_loss: 2.0139 - dense_3_loss: 0.5900 - dense_4_loss: 1.7225 - emotion_acc: 0.3199 - val_loss: 1.7942 - val_emotion_loss: 1.6274 - val_dense_3_loss: 0.4647 - val_dense_4_loss: 1.2041 - val_emotion_acc: 0.3949
# Epoch 5/10
# 1982/1982 [==============================] - 8s 4ms/step - loss: 1.6006 - emotion_loss: 1.4538 - dense_3_loss: 0.4514 - dense_4_loss: 1.0167 - emotion_acc: 0.4420 - val_loss: 1.5056 - val_emotion_loss: 1.3788 - val_dense_3_loss: 0.4336 - val_dense_4_loss: 0.8343 - val_emotion_acc: 0.4917
# Epoch 6/10
# 1982/1982 [==============================] - 9s 4ms/step - loss: 1.4088 - emotion_loss: 1.2873 - dense_3_loss: 0.4217 - dense_4_loss: 0.7937 - emotion_acc: 0.5081 - val_loss: 1.3691 - val_emotion_loss: 1.2556 - val_dense_3_loss: 0.4173 - val_dense_4_loss: 0.7170 - val_emotion_acc: 0.5416
# Epoch 7/10
# 1982/1982 [==============================] - 10s 5ms/step - loss: 1.2887 - emotion_loss: 1.1767 - dense_3_loss: 0.4108 - dense_4_loss: 0.7092 - emotion_acc: 0.5545 - val_loss: 1.2943 - val_emotion_loss: 1.1858 - val_dense_3_loss: 0.4060 - val_dense_4_loss: 0.6795 - val_emotion_acc: 0.5688
# Epoch 8/10
# 1982/1982 [==============================] - 10s 5ms/step - loss: 1.2017 - emotion_loss: 1.0944 - dense_3_loss: 0.4027 - dense_4_loss: 0.6708 - emotion_acc: 0.5893 - val_loss: 1.2318 - val_emotion_loss: 1.1265 - val_dense_3_loss: 0.4004 - val_dense_4_loss: 0.6527 - val_emotion_acc: 0.6112
# Epoch 9/10
# 1982/1982 [==============================] - 11s 5ms/step - loss: 1.1445 - emotion_loss: 1.0391 - dense_3_loss: 0.3988 - dense_4_loss: 0.6549 - emotion_acc: 0.6196 - val_loss: 1.1872 - val_emotion_loss: 1.0834 - val_dense_3_loss: 0.3967 - val_dense_4_loss: 0.6408 - val_emotion_acc: 0.6142
# Epoch 10/10
# 1982/1982 [==============================] - 10s 5ms/step - loss: 1.0859 - emotion_loss: 0.9833 - dense_3_loss: 0.3951 - dense_4_loss: 0.6307 - emotion_acc: 0.6443 - val_loss: 1.1309 - val_emotion_loss: 1.0320 - val_dense_3_loss: 0.3930 - val_dense_4_loss: 0.5965 - val_emotion_acc: 0.6293

# %%
pred = model.predict(X_test)[0]
y_pred = [np.argmax(p) for p in pred]
y_true = [np.argmax(p) for p in Y_test]

print classification_report(y_true, y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.75      0.56      0.64       149
#           1       0.00      0.00      0.00        10
#           2       0.79      0.27      0.40        71
#           3       0.45      0.80      0.58        74
#           4       0.67      0.88      0.76       163
#           5       0.64      0.14      0.23        64
#           6       0.61      0.78      0.68       130
#
# avg / total       0.65      0.63      0.60       661

# %%
# homework: to get 65% F1
